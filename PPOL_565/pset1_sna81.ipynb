# %% [markdown]
# # Problem Set #1
# ## Name: Sahithi Adari
# ### Date: 02/07/2021

# %%
import requests # For downloading the website
from bs4 import BeautifulSoup # For parsing the website
import pandas as pd
import numpy as np
import json
import csv

# %% [markdown]
# ## Part 1

# %%
# REVIEW the website to be scraped
webpage = 'http://www.gutenberg.org/'

# %%
# ACCESS
server_response = requests.get(webpage)

# %%
# PARSE/Parsing the content 
soup = BeautifulSoup(server_response.content, 'html.parser')

# Previewing the raw the code of the downloaded website 
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Free eBooks | Project Gutenberg
#   </title>
#   <link href="/gutenberg/style.css?v=1.1" rel="stylesheet"/>
#   <link href="/gutenberg/collapsible.css?1.1" rel="stylesheet"/>
#   <link href="/gutenberg/new_nav.css?v=1.321231" rel="stylesheet"/>
#   <link href="/gutenberg/pg-desktop-one.css" rel="stylesheet"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="books, ebooks, free, kindle, android, iphone, ipad" name="keywords">
#    <meta content="wucOEvSnj5kP3Ts_36OfP64laakK-1mVTg-ptrGC9io" name="google-site-verification"/>
#    <meta content="4WNaCljsE-A82vP_ih2H_UqXZvM" name="alexaVerifyID"/>
#    <link href="https://www.gnu.org/copyleft/fdl.html" rel="copyright">
#     <link href="/gutenberg/favicon.ico?v=1.1" rel="shortcut icon">
#      <meta content="Project Gutenberg" property="og:title"/>
#      <meta content="website" property="og:type"/>
#      <meta content="https://www.gutenberg.org/" property="og:url"/>
#      <meta content="Project Gutenberg is a library of free eBooks." property="og:description"/>
#      <meta content="615269807" property="fb:admins"/>
#      <meta content="115319388529183" property="fb:app_id"/>
#      <meta content="Project Gutenberg" property="og:site_name"/>
#      <meta content="https://www.gutenberg.org/gutenberg/pg-logo-144x144.png" property="og:image"/>
#     </link>
#    </link>
#   </meta>
#  </head>
#  <body>
#   <div class="container">
#    <!-- start body -->
#    <nav>
#     <!--<div id="main_logo"> -->
#     <a class="no-hover" href="/" id="main_logo">
#      <img alt="Project Gutenberg" draggable="false" src="/gutenberg/pg-logo-129x80.png"/>
#     </a>
#     <!--	</div>-->
#     <div id="menu">
#      <label for="tm" id="toggle-menu">
#       Menu
#       <span class="drop-icon">
#        ▾
#       </span>
#      </label>
#      <input id="tm" type="checkbox"/>
#      <ul class="main-menu cf">
#       <li>
#        <a href="/about/">
#         About
#         <span class="drop-icon">
#          ▾
#         </span>
#        </a>
#        <label class="drop-icon" for="sm0" title="Toggle Drop-down">
#         ▾
#        </label>
#        <input id="sm0" type="checkbox"/>
#        <ul class="sub-menu">
#         <li>
#          <a href="/about/">
#           About Project Gutenberg
#          </a>
#         </li>
#         <li>
#          <a href="/policy/collection_development.html">
#           Collection Development
#          </a>
#         </li>
#         <li>
#          <a href="/about/contact_information.html">
#           Contact Us
#          </a>
#         </li>
#         <li>
#          <a href="/about/background/">
#           History &amp; Philosophy
#          </a>
#         </li>
#         <li>
#          <a href="/policy/permission.html">
#           Permissions &amp; License
#          </a>
#         </li>
#         <li>
#          <a href="/policy/privacy_policy.html">
#           Privacy Policy
#          </a>
#         </li>
#         <li>
#          <a href="/policy/terms_of_use.html">
#           Terms of Use
#          </a>
#         </li>
#        </ul>
#       </li>
#       <li>
#        <a href="/ebooks/">
#         Search and Browse
#         <span class="drop-icon">
#          ▾
#         </span>
#        </a>
#        <label class="drop-icon" for="sm8" title="Toggle Drop-down">
#         ▾
#        </label>
#        <input id="sm8" type="checkbox"/>
#        <ul class="sub-menu">
#         <li>
#          <a href="/ebooks/">
#           Book Search
#          </a>
#         </li>
#         <li>
#          <a href="/ebooks/bookshelf/">
#           Bookshelves
#          </a>
#         </li>
#         <li>
#          <a href="/browse/scores/top">
#           Frequently Downloaded
#          </a>
#         </li>
#         <li>
#          <a href="/ebooks/offline_catalogs.html">
#           Offline Catalogs
#          </a>
#         </li>
#        </ul>
#       </li>
#       <li>
#        <a href="/help/">
#         Help
#         <span class="drop-icon">
#          ▾
#         </span>
#        </a>
#        <label class="drop-icon" for="sm3" title="Toggle Drop-down">
#         ▾
#        </label>
#        <input id="sm3" type="checkbox"/>
#        <ul class="sub-menu">
#         <li>
#          <a href="/help/">
#           All help topics →
#          </a>
#         </li>
#         <li>
#          <a href="/help/copyright.html">
#           Copyright Procedures
#          </a>
#         </li>
#         <li>
#          <a href="/help/errata.html">
#           Errata, Fixes and Bug Reports
#          </a>
#         </li>
#         <li>
#          <a href="/help/file_formats.html">
#           File Formats
#          </a>
#         </li>
#         <li>
#          <a href="/help/faq.html">
#           Frequently Asked Questions
#          </a>
#         </li>
#         <li>
#          <a href="/policy/">
#           Policies →
#          </a>
#         </li>
#         <li>
#          <a href="/help/public_domain_ebook_submission.html">
#           Public Domain eBook Submission
#          </a>
#         </li>
#         <li>
#          <a href="/help/submitting_your_own_work.html">
#           Submitting Your Own Work
#          </a>
#         </li>
#         <li>
#          <a href="/help/mobile.html">
#           Tablets, Phones and eReaders
#          </a>
#         </li>
#         <li>
#          <a href="/attic/">
#           The Attic →
#          </a>
#         </li>
#        </ul>
#       </li>
#       <li>
#        <a href="/donate/">
#         Donate
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="donate">
#      <div class="searchbox">
#       <form accept-charset="utf-8" action="/ebooks/search/" class="searchbox" enctype="multipart/form-data" method="get">
#        <input class="searchInput" id="menu-book-search" maxlength="80" name="query" placeholder="  Quick search" size="20" tabindex="20" title="Quick search" type="text" value=""/>
#        <input name="submit_search" style="vertical-align:middle;" type="submit" value="Go!"/>
#       </form>
#      </div>
#      <form action="https://www.paypal.com/cgi-bin/webscr" class="donatelink" method="post" target="new">
#       <p>
#        <a href="/donate/">
#         Donation
#        </a>
#       </p>
#       <input name="cmd" type="hidden" value="_s-xclick"/>
#       <input name="hosted_button_id" type="hidden" value="XKAL6BZL3YPSN"/>
#       <input alt="Donate via PayPal" class="donbtn" name="submit" src="/pics/en_US.gif" type="image"/>
#      </form>
#     </div>
#    </nav>
#    <div class="page_content">
#     <!-- start content -->
#     <h1 id="welcome-to-project-gutenberg">
#      Welcome to Project Gutenberg
#     </h1>
#     <h2 class="subtitle">
#      Project Gutenberg is a library of over 60,000 free eBooks
#     </h2>
#     <div class="box_announce">
#      <p>
#       <strong>
#        This is the new Project Gutenberg site
#       </strong>
#       See the
#       <a href="/help/new_website">
#        new website
#       </a>
#       page for information about currently known issues, and how to report problems or suggest changes.
#      </p>
#     </div>
#     <p>
#      Choose among free epub and Kindle eBooks, download them or read them online. You will find the world’s great literature here, with focus on older works for which U.S. copyright has expired. Thousands of volunteers digitized and diligently proofread the eBooks, for you to enjoy.
#     </p>
#     <!-- Latest Books -->
#     <div class="library" style="overflow-x: auto; position: relative;">
#      <div class="box_shadow" style="min-width: 1260px;">
#       <div class="lib latest no-select">
#        <a href="/ebooks/64504" target="_top" title="Working with the Hands
# Being a Sequel to &quot;Up from Slavery,&quot; Covering the Author's Experiences in Industrial Training at Tuskegee">
#         <div class="cover_image">
#          <div class="cover_img">
#           <img alt="Working with the Hands
# Being a Sequel to &quot;Up from Slavery,&quot; Covering the Author's Experiences in Industrial Training at Tuskegee" draggable="false" src="/cache/epub/64504/pg64504.cover.medium.jpg" title="Working with the Hands
# Being a Sequel to &quot;Up from Slavery,&quot; Covering the Author's Experiences in Industrial Training at Tuskegee"/>
#          </div>
#          <div class="cover_title">
#           <h5>
#            Working with the Hands
#           </h5>
#          </div>
#         </div>
#        </a>
#        <a href="/ebooks/64503" target="_top" title="Christianity in relation to Freethought, Scepticism, and Faith
# Three discourses by the Bishop of Peterborough with special replies by Mr. C. Bradlaugh">
#         <div class="cover_image">
#          <div class="cover_img">
#           <img alt="Christianity in relation to Freethought, Scepticism, and Faith
# Three discourses by the Bishop of Peterborough with special replies by Mr. C. Bradlaugh" draggable="false" src="/cache/epub/64503/pg64503.cover.medium.jpg" title="Christianity in relation to Freethought, Scepticism, and Faith
# Three discourses by the Bishop of Peterborough with special replies by Mr. C. Bradlaugh"/>
#          </div>
#          <div class="cover_title">
#           <h5>
#            Christianity in relation to Freethought, Scepticism, and Faith
#           </h5>
#          </div>
#         </div>
#        </a>
#        <a href="/ebooks/64501" target="_top" title="Életemből (I. rész)
# Igaz történetek. Örök emlékek. Humor. Utleirás.">
#         <div class="cover_image">
#          <div class="cover_img">
#           <img alt="Életemből (I. rész)
# Igaz történetek. Örök emlékek. Humor. Utleirás." draggable="false" src="/cache/epub/64501/pg64501.cover.medium.jpg" title="Életemből (I. rész)
# Igaz történetek. Örök emlékek. Humor. Utleirás."/>
#          </div>
#          <div class="cover_title">
#           <h5>
#            Életemből (I. rész)
#           </h5>
#          </div>
#         </div>
#        </a>
#        <a href="/ebooks/64500" target="_top" title="Biology versus Theology. The Bible: irreconcilable with Science, Experience, and even its own statements">
#         <div class="cover_image">
#          <div class="cover_img">
#           <img alt="Biology versus Theology. The Bible: irreconcilable with Science, Experience, and even its own statements" draggable="false" src="/cache/epub/64500/pg64500.cover.medium.jpg" title="Biology versus Theology. The Bible: irreconcilable with Science, Experience, and even its own statements"/>
#          </div>
#          <div class="cover_title">
#           <h5>
#            Biology versus Theology. The Bible: irreconcilable with Science, Experience, and
#           </h5>
#          </div>
#         </div>
#        </a>
#        <a href="/ebooks/64499" target="_top" title="Darwinism.  The Noachian Flood">
#         <div class="cover_image">
#          <div class="cover_img">
#           <img alt="Darwinism.  The Noachian Flood" draggable="false" src="/cache/epub/64499/pg64499.cover.medium.jpg" title="Darwinism.  The Noachian Flood"/>
#          </div>
#          <div class="cover_title">
#           <h5>
#            Darwinism.  The Noachian Flood
#           </h5>
#          </div>
#         </div>
#        </a>
#        <a href="/ebooks/64498" target="_top" title="Animals' Rights Considered in Relation to Social Progress">
#         <div class="cover_image">
#          <div class="cover_img">
#           <img alt="Animals' Rights Considered in Relation to Social Progress" draggable="false" src="/cache/epub/64498/pg64498.cover.medium.jpg" title="Animals' Rights Considered in Relation to Social Progress"/>
#          </div>
#          <div class="cover_title">
#           <h5>
#            Animals' Rights Considered in Relation to Social Progress
#           </h5>
#          </div>
#         </div>
#        </a>
#        <a href="/ebooks/64497" target="_top" title="Murderer's Base">
#         <div class="cover_image">
#          <div class="cover_img">
#           <img alt="Murderer's Base" draggable="false" src="/cache/epub/64497/pg64497.cover.medium.jpg" title="Murderer's Base"/>
#          </div>
#          <div class="cover_title">
#           <h5>
#            Murderer's Base
#           </h5>
#          </div>
#         </div>
#        </a>
#        <a href="/ebooks/64496" target="_top" title="Moses, not Darwin
# A Sermon">
#         <div class="cover_image">
#          <div class="cover_img">
#           <img alt="Moses, not Darwin
# A Sermon" draggable="false" src="/cache/epub/64496/pg64496.cover.medium.jpg" title="Moses, not Darwin
# A Sermon"/>
#          </div>
#          <div class="cover_title">
#           <h5>
#            Moses, not Darwin
#           </h5>
#          </div>
#         </div>
#        </a>
#        <a href="/ebooks/64495" target="_top" title="The Palace of Glass and the Gathering of the People
# A Book for the Exhibition">
#         <div class="cover_image">
#          <div class="cover_img">
#           <img alt="The Palace of Glass and the Gathering of the People
# A Book for the Exhibition" draggable="false" src="/cache/epub/64495/pg64495.cover.medium.jpg" title="The Palace of Glass and the Gathering of the People
# A Book for the Exhibition"/>
#          </div>
#          <div class="cover_title">
#           <h5>
#            The Palace of Glass and the Gathering of the People
#           </h5>
#          </div>
#         </div>
#        </a>
#        <a href="/ebooks/64494" target="_top" title="Knott's pop-corn book
# Dedicated to the health the happiness the wealth of all people">
#         <div class="cover_image">
#          <div class="cover_img">
#           <img alt="Knott's pop-corn book
# Dedicated to the health the happiness the wealth of all people" draggable="false" src="/cache/epub/64494/pg64494.cover.medium.jpg" title="Knott's pop-corn book
# Dedicated to the health the happiness the wealth of all people"/>
#          </div>
#          <div class="cover_title">
#           <h5>
#            Knott's pop corn book
#           </h5>
#          </div>
#         </div>
#        </a>
#       </div>
#       <p>
#        <i>
#         Some of our latest eBooks
#        </i>
#        <a href="/browse/recent/last1">
#         Click Here for more latest books!
#        </a>
#       </p>
#      </div>
#     </div>
#     <!-- ending latest books -->
#     <p>
#      <strong>
#       Planned service change
#      </strong>
#      In April 2021, www.gutenberg.org plans to remove unencrypted access (http), and will only offer https. The collection remains available from mirrors, as well as via unencrypted ftp and rsync.
#     </p>
#     <p>
#      <strong>
#       No fee or registration!
#      </strong>
#      Everything from Project Gutenberg is gratis, libre, and completely without cost to readers. If you find Project Gutenberg useful, please consider a small donation, to help Project Gutenberg digitize more books, maintain its online presence, and improve Project Gutenberg programs and offerings. Other ways to help include digitizing, proofreading and formatting, or reporting errors.
#     </p>
#     <p>
#      <strong>
#       No special apps needed!
#      </strong>
#      Project Gutenberg eBooks require no special apps to read, just the regular Web browsers or eBook readers that are included with computers and mobile devices. There have been reports of sites that charge fees for custom apps, or for the same eBooks that are freely available from Project Gutenberg. Some of the apps might have worthwhile features, but none are required to enjoy Project Gutenberg eBooks.
#     </p>
#     <h2 id="find-free-ebooks">
#      Find Free eBooks
#     </h2>
#     <ul>
#      <li>
#       <a href="/ebooks/">
#        Search and browse
#       </a>
#       . By author, title, subject, language, type, popularity, and more.
#      </li>
#      <li>
#       <a href="/ebooks/bookshelf/">
#        Bookshelves
#       </a>
#       of related eBooks.
#      </li>
#      <li>
#       <a href="/browse/scores/top">
#        Frequently downloaded
#       </a>
#       : Top 100, or ranked
#       <a href="/ebooks/search/?sort_order=downloads">
#        by popularity
#       </a>
#       .
#      </li>
#      <li>
#       <a href="/ebooks/offline_catalogs.html">
#        Offline catalogs
#       </a>
#       : handy eBook listings and metadata to consult offline.
#      </li>
#      <li>
#       <a href="/ebooks/search/?query=&amp;submit_search=Search&amp;sort_order=release_date">
#        Recently added
#       </a>
#       . The latest new and updated eBooks.
#      </li>
#      <li>
#       Visit
#       <a href="http://self.gutenberg.org">
#        self.gutenberg.org
#       </a>
#       for free eBooks by contemporary authors.
#      </li>
#     </ul>
#     <h2 id="get-help">
#      Get Help
#     </h2>
#     <div class="box_shadow">
#      <ul>
#       <li>
#        <a href="/help/faq.html">
#         Frequently Asked Questions
#        </a>
#        about Project Gutenberg.
#       </li>
#       <li>
#        <a href="/help/">
#         Help, How-To and FAQs
#        </a>
#        : In depth information about many topics.
#       </li>
#       <li>
#        <a href="/help/mobile.html">
#         Tablets, phones and eReaders How-To
#        </a>
#        : Using tablets, Kindle, Nook, cell phone, and other mobile devices and readers.
#       </li>
#      </ul>
#     </div>
#     <h2 id="how-to-help">
#      How to Help
#     </h2>
#     <ul>
#      <li>
#       <a href="https://www.pgdp.net">
#        Distributed Proofreaders
#       </a>
#       welcomes new volunteers. This is the main source of new Project Gutenberg eBooks. Getting started is easy, and just a page a day will help!
#      </li>
#      <li>
#       <a href="/help/errata.html">
#        Fix and improve
#       </a>
#       Project Gutenberg by reporting errors, bugs, typos, and suggesting changes.
#      </li>
#      <li>
#       Record audiobooks with our affiliate,
#       <a href="https://librivox.org">
#        LibriVox
#       </a>
#       .
#      </li>
#     </ul>
#     <h2 id="special-areas">
#      Special Areas
#     </h2>
#     <ul>
#      <li>
#       <a href="/about/">
#        About Project Gutenberg
#       </a>
#       .
#      </li>
#      <li>
#       <a href="/donate/">
#        Donating to Project Gutenberg
#       </a>
#       .
#      </li>
#      <li>
#       <a href="/ebooks/feeds.html">
#        Feeds
#       </a>
#       of new eBooks.
#      </li>
#      <li>
#       <a href="/policy/linking.html">
#        Linking to Project Gutenberg
#       </a>
#       and
#       <a href="/policy/robot_access.html">
#        roboting or crawling
#       </a>
#       the site.
#      </li>
#      <li>
#       <a href="/about/partners_affiliates.html">
#        Partners and affiliates
#       </a>
#       .
#      </li>
#      <li>
#       <a href="/policy/permission.html">
#        Permissions, copyright, licensing, and trademark information
#       </a>
#       .
#      </li>
#      <li>
#       What does
#       <a href="/about/background/free_ebook.html">
#        free eBook
#       </a>
#       (No Cost or Freedom?) mean?
#      </li>
#     </ul>
#     <h2 id="terms-of-use">
#      Terms of Use
#     </h2>
#     <div class="box_shadow">
#      <p>
#       Project Gutenberg eBooks may be freely used in the United States because most are not protected by U.S. copyright law. They may not be free of copyright in other countries. Readers outside of the United States must check the copyright terms of their countries before accessing, downloading or redistributing eBooks. We also have a number of copyrighted titles, for which the copyright holder has given permission for unlimited non-commercial worldwide use.
#      </p>
#      <p>
#       The Project Gutenberg website is for human users only. Use of automated tools to access the website may trigger a block of your access. This site utilizes cookies, captchas and related technologies to help assure the site is maximally available for human users. See full terms of use
#       <a href="/policy/terms_of_use.html">
#        here
#       </a>
#       .
#      </p>
#     </div>
#     <h2 id="social-media">
#      Social Media
#     </h2>
#     <ul class="icon-list">
#      <li>
#       <a href="https://www.facebook.com/project.gutenberg">
#        <img alt="Facebook Icon" src="/gutenberg/f_icon.png"/>
#       </a>
#      </li>
#      <li>
#       <a href="https://twitter.com/gutenberg_org">
#        <img alt="Twitter Icon" src="/gutenberg/t_icon.png"/>
#       </a>
#      </li>
#      <li>
#       News feeds of new eBooks:
#      </li>
#      <li>
#       <a href="https://www.facebook.com/gutenberg.new">
#        <img alt="Facebook News Feed Icon" src="/gutenberg/f_news_icon.png"/>
#       </a>
#      </li>
#      <li>
#       <a href="https://twitter.com/gutenberg_new">
#        <img alt="Twitter News Feed Icon" src="/gutenberg/t_news_icon.png"/>
#       </a>
#      </li>
#     </ul>
#     <!-- ## Contact Info
#
# - [Contact Information](/about/contact_information.html): How to get in touch.
# - [Mailing lists](https://lists.pglaf.org/): Subscribe to the monthly newsletter. -->
#    </div>
#    <!--content ending-->
#   </div>
#   <!-- body ending -->
#   <div class="footer">
#    <!-- start footer -->
#    <ul>
#     <li>
#      <a href="/policy/privacy_policy.html" title="Privacy Policy">
#       Privacy policy
#      </a>
#     </li>
#     <li>
#      <a href="/about/" title="About Project Gutenberg">
#       About Project Gutenberg
#      </a>
#     </li>
#     <li>
#      <a href="/policy/terms_of_use.html" title="Terms of Use">
#       Terms of Use
#      </a>
#     </li>
#     <li>
#      <a href="/about/contact_information.html" title="Contact Information">
#       Contact Information
#      </a>
#     </li>
#     <li>
#      <a href="/help/" title="Get Help">
#       Get Help
#      </a>
#     </li>
#    </ul>
#    <a href="https://www.ibiblio.org/" title="Project Gutenberg is hosted by ibiblio">
#     <img alt="iBiblio" src="/gutenberg/ibiblio-logo.png"/>
#    </a>
#   </div>
#   <!-- footer ending-->
#  </body>
# </html>

# %% [markdown]
# ### Question 1

# %% [markdown]
# If we take a look at the raw code we can see that there are three different HTML tags right at the top of the output: `<head>`, `<title>`, and `<link>`. The `<head>` tag is used as a container for the metadata of the webpage. Since the metadata of the page refers to the HTML document itself, it is not displayed on the website. The `<title>` tag defines the title of document and can usually be seen at the top of each new website/browser tab. Lastly the `<link>` tag defines a relationship between the current HTML document and, usually, an external stylesheet. Because all of the `<link>` tags are within `<head>` tag, this means these stylesheets are located in the metadata of the website and not necessarily viewable to a user.
#
# Definitions for the various HTML tags were liberally copied and modified from the [W3 School website](https://www.w3schools.com/tags/).

# %% [markdown]
# ### Question 2

# %%
# ACCESS 
# Requesting the contents of the webpage and displaying the HTTP response code
server_response.status_code
# Out:
# 200

# %% [markdown]
# The HTTP response code is `200`.

# %% [markdown]
# ### Question 3

# %%
# PARSE/Finding all the instance on the webpage containing the "h2" tags (version 1)
[i for i in soup.find_all('h2')]
# Out:
# [<h2 class="subtitle">Project Gutenberg is a library of over 60,000 free eBooks</h2>,
#  <h2 id="find-free-ebooks">Find Free eBooks</h2>,
#  <h2 id="get-help">Get Help</h2>,
#  <h2 id="how-to-help">How to Help</h2>,
#  <h2 id="special-areas">Special Areas</h2>,
#  <h2 id="terms-of-use">Terms of Use</h2>,
#  <h2 id="social-media">Social Media</h2>]

# %%
# PARSE/Finding all the instance on the webpage containing the "h2" tags (version 2)
soup.find_all('h2')
# Out:
# [<h2 class="subtitle">Project Gutenberg is a library of over 60,000 free eBooks</h2>,
#  <h2 id="find-free-ebooks">Find Free eBooks</h2>,
#  <h2 id="get-help">Get Help</h2>,
#  <h2 id="how-to-help">How to Help</h2>,
#  <h2 id="special-areas">Special Areas</h2>,
#  <h2 id="terms-of-use">Terms of Use</h2>,
#  <h2 id="social-media">Social Media</h2>]

# %% [markdown]
# ### Question 4

# %%
# PARSE/Finding all the instance on the webpage containing the "li" tags
li_list = [] # Creating an empty list
for tag in soup.find_all('li'): #for loop that grabs the text of each "li" tag
    words = tag.text
    li_list.append(words)

# %%
# Slicing the part of the li_list for the text that is included as bullet points on the website
li_list[25:44]
# Out:
# ['Search and browse. By author, title, subject, language, type, popularity, and more.',
#  'Bookshelves of related eBooks.',
#  'Frequently downloaded: Top 100, or ranked by popularity.',
#  'Offline catalogs: handy eBook listings and metadata to consult offline.',
#  'Recently added. The latest new and updated eBooks.',
#  'Visit self.gutenberg.org for free eBooks by contemporary authors.',
#  'Frequently Asked Questions about Project Gutenberg.',
#  'Help, How-To and FAQs: In depth information about many topics.',
#  'Tablets, phones and eReaders How-To: Using tablets, Kindle, Nook, cell phone, and other mobile devices and readers.',
#  'Distributed Proofreaders welcomes new volunteers. This is the main source of new Project Gutenberg eBooks. Getting started is easy, and just a page a day will help!',
#  'Fix and improve Project Gutenberg by reporting errors, bugs, typos, and suggesting changes.',
#  'Record audiobooks with our affiliate, LibriVox.',
#  'About Project Gutenberg.',
#  'Donating to Project Gutenberg.',
#  'Feeds of new eBooks.',
#  'Linking to Project Gutenberg and roboting or crawling the site.',
#  'Partners and affiliates.',
#  'Permissions, copyright, licensing, and trademark information.',
#  'What does free eBook (No Cost or Freedom?) mean?']

# %% [markdown]
# ## Part 2

# %% [markdown]
# ### Question 1

# %%
# REVIEW
# ============================
host = 'https://itunes.apple.com/search'

# %%
# ACCESS
# ============================
# Building the api GET request
# Including the parameters limit = 200 to get 200 attributes and media = music to only get songs 
params = "?term=EPIK+HIGH&limit=200&media=music"
url = host + params

# %%
# Checking the HTTP response code
response = requests.request('GET', url)
response.status_code
# Out:
# 200

# %%
# PARSE
# ============================
# Parsing the JSON data into a python dictionary
music = response.json()

# %%
# TRANSFORM
# ============================
# Displaying the result in an easy-to-read format
print(json.dumps(music, indent=4, sort_keys=True))
data = music["results"]
# Out:
# {
#     "resultCount": 200,
#     "results": [
#         {
#             "artistId": 139334133,
#             "artistName": "Epik High",
#             "artistViewUrl": "https://music.apple.com/us/artist/epik-high/139334133?uo=4",
#             "artworkUrl100": "https://is5-ssl.mzstatic.com/image/thumb/Music118/v4/82/48/4d/82484d36-358d-9e5a-f5b9-58004a4c895e/source/100x100bb.jpg",
#             "artworkUrl30": "https://is5-ssl.mzstatic.com/image/thumb/Music118/v4/82/48/4d/82484d36-358d-9e5a-f5b9-58004a4c895e/source/30x30bb.jpg",
#             "artworkUrl60": "https://is5-ssl.mzstatic.com/image/thumb/Music118/v4/82/48/4d/82484d36-358d-9e5a-f5b9-58004a4c895e/source/60x60bb.jpg",
#             "collectionCensoredName": "SHOEBOX",
#             "collectionExplicitness": "explicit",
#             "collectionId": 1316881090,
#             "collectionName": "SHOEBOX",
#             "collectionPrice": 11.99,
#             "collectionViewUrl": "https://music.apple.com/us/album/born-hater-feat-beenzino-verbal-jint-b-i-mino-bobby/1316881090?i=1316881196&uo=4",
#             "contentAdvisoryRating": "Explicit",
#             "country": "USA",
#             "currency": "USD",
#             "discCount": 1,
#             "discNumber": 1,
#             "isStreamable": true,
#             "kind": "song",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview128/v4/99/26/ac/9926ac79-f047-daba-16bc-101bd0909c29/mzaf_7628196266232539424.plus.aac.p.m4a",
#             "primaryGenreName": "Hip-Hop/Rap",
#             "releaseDate": "2014-10-21T12:00:00Z",
#             "trackCensoredName": "Born Hater (feat. Beenzino, Verbal Jint, B.I., MINO & BOBBY)",
#             "trackCount": 12,
#             "trackExplicitness": "explicit",
#             "trackId": 1316881196,
#             "trackName": "Born Hater (feat. Beenzino, Verbal Jint, B.I., MINO & BOBBY)",
#             "trackNumber": 8,
#             "trackPrice": 1.29,
#             "trackTimeMillis": 327127,
#             "trackViewUrl": "https://music.apple.com/us/album/born-hater-feat-beenzino-verbal-jint-b-i-mino-bobby/1316881090?i=1316881196&uo=4",
#             "wrapperType": "track"
#         },
#         {
#             "artistId": 139334133,
#             "artistName": "Epik High",
#             "artistViewUrl": "https://music.apple.com/us/artist/epik-high/139334133?uo=4",
#             "artworkUrl100": "https://is5-ssl.mzstatic.com/image/thumb/Music118/v4/82/48/4d/82484d36-358d-9e5a-f5b9-58004a4c895e/source/100x100bb.jpg",
#             "artworkUrl30": "https://is5-ssl.mzstatic.com/image/thumb/Music118/v4/82/48/4d/82484d36-358d-9e5a-f5b9-58004a4c895e/source/30x30bb.jpg",
#             "artworkUrl60": "https://is5-ssl.mzstatic.com/image/thumb/Music118/v4/82/48/4d/82484d36-358d-9e5a-f5b9-58004a4c895e/source/60x60bb.jpg",
#             "collectionCensoredName": "SHOEBOX",
#             "collectionExplicitness": "explicit",
#             "collectionId": 1316881090,
#             "collectionName": "SHOEBOX",
#             "collectionPrice": 11.99,
#             "collectionViewUrl": "https://music.apple.com/us/album/eyes-nose-lips-feat-taeyang/1316881090?i=1316881199&uo=4",
#             "country": "USA",
#             "currency": "USD",
#             "discCount": 1,
#             "discNumber": 1,
#             "isStreamable": true,
#             "kind": "song",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview128/v4/6c/eb/1c/6ceb1c95-b9ec-7ffa-4bfe-8ceaf8181875/mzaf_8493074121993984235.plus.aac.p.m4a",
#             "primaryGenreName": "Hip-Hop/Rap",
#             "releaseDate": "2014-10-21T12:00:00Z",
#             "trackCensoredName": "Eyes Nose Lips (feat. TAEYANG)",
#             "trackCount": 12,
#             "trackExplicitness": "notExplicit",
#             "trackId": 1316881199,
#             "trackName": "Eyes Nose Lips (feat. TAEYANG)",
#             "trackNumber": 11,
#             "trackPrice": 1.29,
#             "trackTimeMillis": 213408,
#             "trackViewUrl": "https://music.apple.com/us/album/eyes-nose-lips-feat-taeyang/1316881090?i=1316881199&uo=4",
#             "wrapperType": "track"
#         },
#         {
#             "artistId": 139334133,
#             "artistName": "Epik High",
#             "artistViewUrl": "https://music.apple.com/us/artist/epik-high/139334133?uo=4",
#             "artworkUrl100": "https://is2-ssl.mzstatic.com/image/thumb/Music128/v4/d4/1a/24/d41a2432-f896-8ea6-bf25-9f9a64caee8a/source/100x100bb.jpg",
#             "artworkUrl30": "https://is2-ssl.mzstatic.com/image/thumb/Music128/v4/d4/1a/24/d41a2432-f896-8ea6-bf25-9f9a64caee8a/source/30x30bb.jpg",
#             "artworkUrl60": "https://is2-ssl.mzstatic.com/image/thumb/Music128/v4/d4/1a/24/d41a2432-f896-8ea6-bf25-9f9a64caee8a/source/60x60bb.jpg",
#             "collectionCensoredName": "99",
#             "collectionExplicitness": "notExplicit",
#             "collectionId": 1330922530,
#             "collectionName": "99",
#             "collectionPrice": 6.99,
#             "collectionViewUrl": "https://music.apple.com/us/album/dont-hate-me/1330922530?i=1330922864&uo=4",
#             "country": "USA",
#             "currency": "USD",
#             "discCount": 1,
#             "discNumber": 1,
#             "isStreamable": true,
#             "kind": "song",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview118/v4/49/d2/44/49d24434-0c06-42cf-1a71-d3ff5d07b28e/mzaf_2716177489405288931.plus.aac.p.m4a",
#             "primaryGenreName": "Hip-Hop/Rap",
#             "releaseDate": "2012-10-19T12:00:00Z",
#             "trackCensoredName": "Don't Hate Me",
#             "trackCount": 8,
#             "trackExplicitness": "notExplicit",
#             "trackId": 1330922864,
#             "trackName": "Don't Hate Me",
#             "trackNumber": 2,
#             "trackPrice": 1.29,
#             "trackTimeMillis": 223592,
#             "trackViewUrl": "https://music.apple.com/us/album/dont-hate-me/1330922530?i=1330922864&uo=4",
#             "wrapperType": "track"
#         },
#         {
#             "artistId": 159061696,
#             "artistName": "Tablo",
#             "artistViewUrl": "https://music.apple.com/us/artist/tablo/159061696?uo=4",
#             "artworkUrl100": "https://is3-ssl.mzstatic.com/image/thumb/Music128/v4/54/36/99/54369995-2ed0-110c-01bd-a79d76aebb14/source/100x100bb.jpg",
#             "artworkUrl30": "https://is3-ssl.mzstatic.com/image/thumb/Music128/v4/54/36/99/54369995-2ed0-110c-01bd-a79d76aebb14/source/30x30bb.jpg",
#             "artworkUrl60": "https://is3-ssl.mzstatic.com/image/thumb/Music128/v4/54/36/99/54369995-2ed0-110c-01bd-a79d76aebb14/source/60x60bb.jpg",
#             "collectionCensoredName": "Fever's End, Pt. 2 - EP",
#             "collectionExplicitness": "notExplicit",
#             "collectionId": 1339457592,
#             "collectionName": "Fever's End, Pt. 2 - EP",
#             "collectionPrice": 3.99,
#             "collectionViewUrl": "https://music.apple.com/us/album/tomorrow-feat-taeyang/1339457592?i=1339457593&uo=4",
#             "country": "USA",
#             "currency": "USD",
#             "discCount": 1,
#             "discNumber": 1,
#             "isStreamable": true,
#             "kind": "song",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview128/v4/36/0f/2e/360f2ec7-e958-5a3b-b08b-447579a43e6e/mzaf_45709959566619697.plus.aac.p.m4a",
#             "primaryGenreName": "Hip-Hop/Rap",
#             "releaseDate": "2011-11-01T12:00:00Z",
#             "trackCensoredName": "Tomorrow (feat. TAEYANG)",
#             "trackCount": 5,
#             "trackExplicitness": "notExplicit",
#             "trackId": 1339457593,
#             "trackName": "Tomorrow (feat. TAEYANG)",
#             "trackNumber": 1,
#             "trackPrice": 1.29,
#             "trackTimeMillis": 252900,
#             "trackViewUrl": "https://music.apple.com/us/album/tomorrow-feat-taeyang/1339457592?i=1339457593&uo=4",
#             "wrapperType": "track"
#         },
#         {
#             "artistId": 139334133,
#             "artistName": "Epik High",
#             "artistViewUrl": "https://music.apple.com/us/artist/epik-high/139334133?uo=4",
#             "artworkUrl100": "https://is3-ssl.mzstatic.com/image/thumb/Music114/v4/02/97/4a/02974ae9-89f9-8b0c-0338-662023eacd49/source/100x100bb.jpg",
#             "artworkUrl30": "https://is3-ssl.mzstatic.com/image/thumb/Music114/v4/02/97/4a/02974ae9-89f9-8b0c-0338-662023eacd49/source/30x30bb.jpg",
#             "artworkUrl60": "https://is3-ssl.mzstatic.com/image/thumb/Music114/v4/02/97/4a/02974ae9-89f9-8b0c-0338-662023eacd49/source/60x60bb.jpg",
#             "collectionCensoredName": "Epik High Is Here \u4e0a, Pt. 1",
#             "collectionExplicitness": "explicit",
#             "collectionId": 1548249682,
#             "collectionName": "Epik High Is Here \u4e0a, Pt. 1",
#             "collectionPrice": 9.99,
#             "collectionViewUrl": "https://music.apple.com/us/album/rosario-feat-cl-zico/1548249682?i=1548249684&uo=4",
#             "contentAdvisoryRating": "Explicit",
#             "country": "USA",
#             "currency": "USD",
#             "discCount": 1,
#             "discNumber": 1,
#             "isStreamable": true,
#             "kind": "song",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview124/v4/d7/f3/cd/d7f3cdbe-e357-a784-dcc3-875e748d2c03/mzaf_6171299484109061526.plus.aac.p.m4a",
#             "primaryGenreName": "Hip-Hop/Rap",
#             "releaseDate": "2021-01-18T12:00:00Z",
#             "trackCensoredName": "Rosario (feat. CL & ZICO)",
#             "trackCount": 10,
#             "trackExplicitness": "explicit",
#             "trackId": 1548249684,
#             "trackName": "Rosario (feat. CL & ZICO)",
#             "trackNumber": 2,
#             "trackPrice": 1.29,
#             "trackTimeMillis": 230066,
#             "trackViewUrl": "https://music.apple.com/us/album/rosario-feat-cl-zico/1548249682?i=1548249684&uo=4",
#             "wrapperType": "track"
#         },
#         {
#             "artistId": 281891356,
#             "artistName": "Gallant x Tablo x Eric Nam",
#             "artistViewUrl": "https://music.apple.com/us/artist/gallant/281891356?uo=4",
#             "artworkUrl100": "https://is1-ssl.mzstatic.com/image/thumb/Music111/v4/1c/96/9f/1c969f3a-ada7-cd6a-fae0-0fcacadb27f5/source/100x100bb.jpg",
#             "artworkUrl30": "https://is1-ssl.mzstatic.com/image/thumb/Music111/v4/1c/96/9f/1c969f3a-ada7-cd6a-fae0-0fcacadb27f5/source/30x30bb.jpg",
#             "artworkUrl60": "https://is1-ssl.mzstatic.com/image/thumb/Music111/v4/1c/96/9f/1c969f3a-ada7-cd6a-fae0-0fcacadb27f5/source/60x60bb.jpg",
#             "collectionCensoredName": "Cave Me In - Single",
#             "collectionExplicitness": "notExplicit",
#             "collectionId": 1197529760,
#             "collectionName": "Cave Me In - Single",
#             "collectionPrice": 1.29,
#             "collectionViewUrl": "https://music.apple.com/us/album/cave-me-in/1197529760?i=1197529770&uo=4",
#             "country": "USA",
#             "currency": "USD",
#             "discCount": 1,
#             "discNumber": 1,
#             "isStreamable": true,
#             "kind": "song",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview82/v4/e7/71/cb/e771cbe0-63aa-acf1-710f-344901ab09f5/mzaf_3073402780209023400.plus.aac.p.m4a",
#             "primaryGenreName": "R&B/Soul",
#             "releaseDate": "2017-01-27T12:00:00Z",
#             "trackCensoredName": "Cave Me In",
#             "trackCount": 1,
#             "trackExplicitness": "notExplicit",
#             "trackId": 1197529770,
#             "trackName": "Cave Me In",
#             "trackNumber": 1,
#             "trackPrice": 1.29,
#             "trackTimeMillis": 214159,
#             "trackViewUrl": "https://music.apple.com/us/album/cave-me-in/1197529760?i=1197529770&uo=4",
#             "wrapperType": "track"
#         },
#         {
#             "artistId": 139334133,
#             "artistName": "Epik High",
#             "artistViewUrl": "https://music.apple.com/us/artist/epik-high/139334133?uo=4",
#             "artworkUrl100": "https://is5-ssl.mzstatic.com/image/thumb/Music118/v4/82/48/4d/82484d36-358d-9e5a-f5b9-58004a4c895e/source/100x100bb.jpg",
#             "artworkUrl30": "https://is5-ssl.mzstatic.com/image/thumb/Music118/v4/82/48/4d/82484d36-358d-9e5a-f5b9-58004a4c895e/source/30x30bb.jpg",
#             "artworkUrl60": "https://is5-ssl.mzstatic.com/image/thumb/Music118/v4/82/48/4d/82484d36-358d-9e5a-f5b9-58004a4c895e/source/60x60bb.jpg",
#             "collectionCensoredName": "SHOEBOX",
#             "collectionExplicitness": "explicit",
#             "collectionId": 1316881090,
#             "collectionName": "SHOEBOX",
#             "collectionPrice": 11.99,
#             "collectionViewUrl": "https://music.apple.com/us/album/happen-ending-feat-joe-won-sun/1316881090?i=1316881190&uo=4",
#             "country": "USA",
#             "currency": "USD",
#             "discCount": 1,
#             "discNumber": 1,
#             "isStreamable": true,
#             "kind": "song",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview128/v4/dd/23/70/dd237092-9635-4757-d617-d4e080dc0096/mzaf_4317142454610659009.plus.aac.p.m4a",
#             "primaryGenreName": "Hip-Hop/Rap",
#             "releaseDate": "2008-09-30T12:00:00Z",
#             "trackCensoredName": "Happen Ending (feat. JOE WON SUN)",
#             "trackCount": 12,
#             "trackExplicitness": "notExplicit",
#             "trackId": 1316881190,
#             "trackName": "Happen Ending (feat. JOE WON SUN)",
#             "trackNumber": 2,
#             "trackPrice": 1.29,
#             "trackTimeMillis": 264349,
#             "trackViewUrl": "https://music.apple.com/us/album/happen-ending-feat-joe-won-sun/1316881090?i=1316881190&uo=4",
#             "wrapperType": "track"
#         },
#         {
#             "artistId": 159061696,
#             "artistName": "Tablo",
#             "artistViewUrl": "https://music.apple.com/us/artist/tablo/159061696?uo=4",
#             "artworkUrl100": "https://is4-ssl.mzstatic.com/image/thumb/Music128/v4/70/82/0e/70820ea7-c346-83a7-eba2-af632d41aec1/source/100x100bb.jpg",
#             "artworkUrl30": "https://is4-ssl.mzstatic.com/image/thumb/Music128/v4/70/82/0e/70820ea7-c346-83a7-eba2-af632d41aec1/source/30x30bb.jpg",
#             "artworkUrl60": "https://is4-ssl.mzstatic.com/image/thumb/Music128/v4/70/82/0e/70820ea7-c346-83a7-eba2-af632d41aec1/source/60x60bb.jpg",
#             "collectionCensoredName": "Fever's End, Pt. 1 - EP",
#             "collectionExplicitness": "notExplicit",
#             "collectionId": 1339095508,
#             "collectionName": "Fever's End, Pt. 1 - EP",
#             "collectionPrice": 3.99,
#             "collectionViewUrl": "https://music.apple.com/us/album/bad-feat-jinsil/1339095508?i=1339095510&uo=4",
#             "country": "USA",
#             "currency": "USD",
#             "discCount": 1,
#             "discNumber": 1,
#             "isStreamable": true,
#             "kind": "song",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview128/v4/9a/5f/28/9a5f28ee-c0f4-56bb-e3a1-03a46e771020/mzaf_3157716752925452865.plus.aac.p.m4a",
#             "primaryGenreName": "Hip-Hop/Rap",
#             "releaseDate": "2011-10-21T12:00:00Z",
#             "trackCensoredName": "Bad (feat. Jinsil)",
#             "trackCount": 5,
#             "trackExplicitness": "notExplicit",
#             "trackId": 1339095510,
#             "trackName": "Bad (feat. Jinsil)",
#             "trackNumber": 2,
#             "trackPrice": 1.29,
#             "trackTimeMillis": 241116,
#             "trackViewUrl": "https://music.apple.com/us/album/bad-feat-jinsil/1339095508?i=1339095510&uo=4",
#             "wrapperType": "track"
#         },
#         {
#             "artistId": 139334133,
#             "artistName": "Epik High",
#             "artistViewUrl": "https://music.apple.com/us/artist/epik-high/139334133?uo=4",
#             "artworkUrl100": "https://is5-ssl.mzstatic.com/image/thumb/Music118/v4/82/48/4d/82484d36-358d-9e5a-f5b9-58004a4c895e/source/100x100bb.jpg",
#             "artworkUrl30": "https://is5-ssl.mzstatic.com/image/thumb/Music118/v4/82/48/4d/82484d36-358d-9e5a-f5b9-58004a4c895e/source/30x30bb.jpg",
#             "artworkUrl60": "https://is5-ssl.mzstatic.com/image/thumb/Music118/v4/82/48/4d/82484d36-358d-9e5a-f5b9-58004a4c895e/source/60x60bb.jpg",
#             "collectionCensoredName": "SHOEBOX",
#             "collectionExplicitness": "explicit",
#             "collectionId": 1316881090,
#             "collectionName": "SHOEBOX",
#             "collectionPrice": 11.99,
#             "collectionViewUrl": "https://music.apple.com/us/album/shoebox-feat-myk/1316881090?i=1316881200&uo=4",
#             "country": "USA",
#             "currency": "USD",
#             "discCount": 1,
#             "discNumber": 1,
#             "isStreamable": true,
#             "kind": "song",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview128/v4/0a/d4/b8/0ad4b812-c608-bb11-c803-355e48a0983b/mzaf_1613420208902749221.plus.aac.p.m4a",
#             "primaryGenreName": "Hip-Hop/Rap",
#             "releaseDate": "2014-10-21T12:00:00Z",
#             "trackCensoredName": "Shoebox (feat. MYK)",
#             "trackCount": 12,
#             "trackExplicitness": "notExplicit",
#             "trackId": 1316881200,
#             "trackName": "Shoebox (feat. MYK)",
#             "trackNumber": 12,
#             "trackPrice": 1.29,
#             "trackTimeMillis": 265051,
#             "trackViewUrl": "https://music.apple.com/us/album/shoebox-feat-myk/1316881090?i=1316881200&uo=4",
#             "wrapperType": "track"
#         },
#         {
#             "artistId": 139334133,
#             "artistName": "Epik High",
#             "artistViewUrl": "https://music.apple.com/us/artist/epik-high/139334133?uo=4",
#             "artworkUrl100": "https://is5-ssl.mzstatic.com/image/thumb/Music118/v4/82/48/4d/82484d36-358d-9e5a-f5b9-58004a4c895e/source/100x100bb.jpg",
#             "artworkUrl30": "https://is5-ssl.mzstatic.com/image/thumb/Music118/v4/82/48/4d/82484d36-358d-9e5a-f5b9-58004a4c895e/source/30x30bb.jpg",
#             "artworkUrl60": "https://is5-ssl.mzstatic.com/image/thumb/Music118/v4/82/48/4d/82484d36-358d-9e5a-f5b9-58004a4c895e/source/60x60bb.jpg",
#             "collectionCensoredName": "SHOEBOX",
#             "collectionExplicitness": "explicit",
#             "collectionId": 1316881090,
#             "collectionName": "SHOEBOX",
#             "collectionPrice": 11.99,
#             "collectionViewUrl": "https://music.apple.com/us/album/spoiler/1316881090?i=1316881192&uo=4",
#             "country": "USA",
#             "currency": "USD",
#             "discCount": 1,
#             "discNumber": 1,
#             "isStreamable": true,
#             "kind": "song",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview128/v4/03/04/93/03049393-5c84-d8d6-968c-05c22ecc05d7/mzaf_6887740596971035879.plus.aac.p.m4a",
#             "primaryGenreName": "Hip-Hop/Rap",
#             "releaseDate": "2008-09-30T12:00:00Z",
#             "trackCensoredName": "Spoiler",
#             "trackCount": 12,
#             "trackExplicitness": "notExplicit",
#             "trackId": 1316881192,
#             "trackName": "Spoiler",
#             "trackNumber": 4,
#             "trackPrice": 1.29,
#             "trackTimeMillis": 277984,
#             "trackViewUrl": "https://music.apple.com/us/album/spoiler/1316881090?i=1316881192&uo=4",
#             "wrapperType": "track"
#         },
#         {
#             "artistId": 139334133,
#             "artistName": "Epik High",
#             "artistViewUrl": "https://music.apple.com/us/artist/epik-high/139334133?uo=4",
#             "artworkUrl100": "https://is2-ssl.mzstatic.com/image/thumb/Music128/v4/d4/1a/24/d41a2432-f896-8ea6-bf25-9f9a64caee8a/source/100x100bb.jpg",
#             "artworkUrl30": "https://is2-ssl.mzstatic.com/image/thumb/Music128/v4/d4/1a/24/d41a2432-f896-8ea6-bf25-9f9a64caee8a/source/30x30bb.jpg",
#             "artworkUrl60": "https://is2-ssl.mzstatic.com/image/thumb/Music128/v4/d4/1a/24/d41a2432-f896-8ea6-bf25-9f9a64caee8a/source/60x60bb.jpg",
#             "collectionCensoredName": "99",
#             "collectionExplicitness": "notExplicit",
#             "collectionId": 1330922530,
#             "collectionName": "99",
#             "collectionPrice": 6.99,
#             "collectionViewUrl": "https://music.apple.com/us/album/up-feat-park-bom/1330922530?i=1330922863&uo=4",
#             "country": "USA",
#             "currency": "USD",
#             "discCount": 1,
#             "discNumber": 1,
#             "isStreamable": true,
#             "kind": "song",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview118/v4/48/ba/db/48badbb2-0f5c-d181-fd4b-25c0d2282c55/mzaf_1411396307981037578.plus.aac.p.m4a",
#             "primaryGenreName": "Hip-Hop/Rap",
#             "releaseDate": "2008-09-30T12:00:00Z",
#             "trackCensoredName": "UP (feat. Park Bom)",
#             "trackCount": 8,
#             "trackExplicitness": "notExplicit",
#             "trackId": 1330922863,
#             "trackName": "UP (feat. Park Bom)",
#             "trackNumber": 1,
#             "trackPrice": 1.29,
#             "trackTimeMillis": 221123,
#             "trackViewUrl": "https://music.apple.com/us/album/up-feat-park-bom/1330922530?i=1330922863&uo=4",
#             "wrapperType": "track"
#         },
#         {
#             "artistId": 139334133,
#             "artistName": "Epik High",
#             "artistViewUrl": "https://music.apple.com/us/artist/epik-high/139334133?uo=4",
#             "artworkUrl100": "https://is5-ssl.mzstatic.com/image/thumb/Music118/v4/82/48/4d/82484d36-358d-9e5a-f5b9-58004a4c895e/source/100x100bb.jpg",
#             "artworkUrl30": "https://is5-ssl.mzstatic.com/image/thumb/Music118/v4/82/48/4d/82484d36-358d-9e5a-f5b9-58004a4c895e/source/30x30bb.jpg",
#             "artworkUrl60": "https://is5-ssl.mzstatic.com/image/thumb/Music118/v4/82/48/4d/82484d36-358d-9e5a-f5b9-58004a4c895e/source/60x60bb.jpg",
#             "collectionCensoredName": "SHOEBOX",
#             "collectionExplicitness": "explicit",
#             "collectionId": 1316881090,
#             "collectionName": "SHOEBOX",
#             "collectionPrice": 11.99,
#             "collectionViewUrl": "https://music.apple.com/us/album/burj-khalifa-feat-yankie-gaeko/1316881090?i=1316881193&uo=4",
#             "country": "USA",
#             "currency": "USD",
#             "discCount": 1,
#             "discNumber": 1,
#             "isStreamable": true,
#             "kind": "song",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview128/v4/59/0f/ec/590fec95-b582-58a4-c862-4cf709e1ac7c/mzaf_7059076082864786796.plus.aac.p.m4a",
#             "primaryGenreName": "Hip-Hop/Rap",
#             "releaseDate": "2014-10-21T12:00:00Z",
#             "trackCensoredName": "Burj Khalifa (feat. Yankie & Gaeko)",
#             "trackCount": 12,
#             "trackExplicitness": "notExplicit",
#             "trackId": 1316881193,
#             "trackName": "Burj Khalifa (feat. Yankie & Gaeko)",
#             "trackNumber": 5,
#             "trackPrice": 1.29,
#             "trackTimeMillis": 265707,
#             "trackViewUrl": "https://music.apple.com/us/album/burj-khalifa-feat-yankie-gaeko/1316881090?i=1316881193&uo=4",
#             "wrapperType": "track"
#         },
#         {
#             "artistId": 139334133,
#             "artistName": "Epik High",
#             "artistViewUrl": "https://music.apple.com/us/artist/epik-high/139334133?uo=4",
#             "artworkUrl100": "https://is5-ssl.mzstatic.com/image/thumb/Music118/v4/82/48/4d/82484d36-358d-9e5a-f5b9-58004a4c895e/source/100x100bb.jpg",
#             "artworkUrl30": "https://is5-ssl.mzstatic.com/image/thumb/Music118/v4/82/48/4d/82484d36-358d-9e5a-f5b9-58004a4c895e/source/30x30bb.jpg",
#             "artworkUrl60": "https://is5-ssl.mzstatic.com/image/thumb/Music118/v4/82/48/4d/82484d36-358d-9e5a-f5b9-58004a4c895e/source/60x60bb.jpg",
#             "collectionCensoredName": "SHOEBOX",
#             "collectionExplicitness": "explicit",
#             "collectionId": 1316881090,
#             "collectionName": "SHOEBOX",
#             "collectionPrice": 11.99,
#             "collectionViewUrl": "https://music.apple.com/us/album/rich-feat-taeyang/1316881090?i=1316881191&uo=4",
#             "country": "USA",
#             "currency": "USD",
#             "discCount": 1,
#             "discNumber": 1,
#             "isStreamable": true,
#             "kind": "song",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview128/v4/b6/b5/e9/b6b5e9e3-ee93-ef96-2cf8-b8762dd5124c/mzaf_441430199772616186.plus.aac.p.m4a",
#             "primaryGenreName": "Hip-Hop/Rap",
#             "releaseDate": "2014-10-21T12:00:00Z",
#             "trackCensoredName": "Rich (feat. TAEYANG)",
#             "trackCount": 12,
#             "trackExplicitness": "notExplicit",
#             "trackId": 1316881191,
#             "trackName": "Rich (feat. TAEYANG)",
#             "trackNumber": 3,
#             "trackPrice": 1.29,
#             "trackTimeMillis": 257199,
#             "trackViewUrl": "https://music.apple.com/us/album/rich-feat-taeyang/1316881090?i=1316881191&uo=4",
#             "wrapperType": "track"
#         },
#         {
#             "artistId": 139334133,
#             "artistName": "Epik High",
#             "artistViewUrl": "https://music.apple.com/us/artist/epik-high/139334133?uo=4",
#             "artworkUrl100": "https://is3-ssl.mzstatic.com/image/thumb/Music114/v4/02/97/4a/02974ae9-89f9-8b0c-0338-662023eacd49/source/100x100bb.jpg",
#             "artworkUrl30": "https://is3-ssl.mzstatic.com/image/thumb/Music114/v4/02/97/4a/02974ae9-89f9-8b0c-0338-662023eacd49/source/30x30bb.jpg",
#             "artworkUrl60": "https://is3-ssl.mzstatic.com/image/thumb/Music114/v4/02/97/4a/02974ae9-89f9-8b0c-0338-662023eacd49/source/60x60bb.jpg",
#             "collectionCensoredName": "Epik High Is Here \u4e0a, Pt. 1",
#             "collectionExplicitness": "explicit",
#             "collectionId": 1548249682,
#             "collectionName": "Epik High Is Here \u4e0a, Pt. 1",
#             "collectionPrice": 9.99,
#             "collectionViewUrl": "https://music.apple.com/us/album/wish-you-were/1548249682?i=1548249692&uo=4",
#             "country": "USA",
#             "currency": "USD",
#             "discCount": 1,
#             "discNumber": 1,
#             "isStreamable": true,
#             "kind": "song",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview124/v4/bd/cb/2d/bdcb2d63-c347-e627-8df3-50fbb45428cd/mzaf_9009358925892266172.plus.aac.p.m4a",
#             "primaryGenreName": "Hip-Hop/Rap",
#             "releaseDate": "2021-01-18T12:00:00Z",
#             "trackCensoredName": "Wish You Were",
#             "trackCount": 10,
#             "trackExplicitness": "notExplicit",
#             "trackId": 1548249692,
#             "trackName": "Wish You Were",
#             "trackNumber": 10,
#             "trackPrice": 1.29,
#             "trackTimeMillis": 92779,
#             "trackViewUrl": "https://music.apple.com/us/album/wish-you-were/1548249682?i=1548249692&uo=4",
#             "wrapperType": "track"
#         },
#         {
#             "artistId": 139334133,
#             "artistName": "Epik High",
#             "artistViewUrl": "https://music.apple.com/us/artist/epik-high/139334133?uo=4",
#             "artworkUrl100": "https://is5-ssl.mzstatic.com/image/thumb/Music118/v4/82/48/4d/82484d36-358d-9e5a-f5b9-58004a4c895e/source/100x100bb.jpg",
#             "artworkUrl30": "https://is5-ssl.mzstatic.com/image/thumb/Music118/v4/82/48/4d/82484d36-358d-9e5a-f5b9-58004a4c895e/source/30x30bb.jpg",
#             "artworkUrl60": "https://is5-ssl.mzstatic.com/image/thumb/Music118/v4/82/48/4d/82484d36-358d-9e5a-f5b9-58004a4c895e/source/60x60bb.jpg",
#             "collectionCensoredName": "SHOEBOX",
#             "collectionExplicitness": "explicit",
#             "collectionId": 1316881090,
#             "collectionName": "SHOEBOX",
#             "collectionPrice": 11.99,
#             "collectionViewUrl": "https://music.apple.com/us/album/we-fight-ourselves-feat-younha/1316881090?i=1316881194&uo=4",
#             "country": "USA",
#             "currency": "USD",
#             "discCount": 1,
#             "discNumber": 1,
#             "isStreamable": true,
#             "kind": "song",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview128/v4/88/16/2b/88162bec-c683-5aa7-0e25-d73708079bd6/mzaf_4117003369177663617.plus.aac.p.m4a",
#             "primaryGenreName": "Hip-Hop/Rap",
#             "releaseDate": "2014-10-21T12:00:00Z",
#             "trackCensoredName": "We Fight Ourselves (feat. Younha)",
#             "trackCount": 12,
#             "trackExplicitness": "notExplicit",
#             "trackId": 1316881194,
#             "trackName": "We Fight Ourselves (feat. Younha)",
#             "trackNumber": 6,
#             "trackPrice": 1.29,
#             "trackTimeMillis": 251367,
#             "trackViewUrl": "https://music.apple.com/us/album/we-fight-ourselves-feat-younha/1316881090?i=1316881194&uo=4",
#             "wrapperType": "track"
#         },
#         {
#             "artistId": 159061696,
#             "artistName": "Tablo",
#             "artistViewUrl": "https://music.apple.com/us/artist/tablo/159061696?uo=4",
#             "artworkUrl100": "https://is3-ssl.mzstatic.com/image/thumb/Music128/v4/54/36/99/54369995-2ed0-110c-01bd-a79d76aebb14/source/100x100bb.jpg",
#             "artworkUrl30": "https://is3-ssl.mzstatic.com/image/thumb/Music128/v4/54/36/99/54369995-2ed0-110c-01bd-a79d76aebb14/source/30x30bb.jpg",
#             "artworkUrl60": "https://is3-ssl.mzstatic.com/image/thumb/Music128/v4/54/36/99/54369995-2ed0-110c-01bd-a79d76aebb14/source/60x60bb.jpg",
#             "collectionCensoredName": "Fever's End, Pt. 2 - EP",
#             "collectionExplicitness": "notExplicit",
#             "collectionId": 1339457592,
#             "collectionName": "Fever's End, Pt. 2 - EP",
#             "collectionPrice": 3.99,
#             "collectionViewUrl": "https://music.apple.com/us/album/thank-you-for-breathing-feat-%EC%96%80%ED%82%A4-%EB%B4%89%ED%83%9C%EA%B7%9C/1339457592?i=1339457596&uo=4",
#             "country": "USA",
#             "currency": "USD",
#             "discCount": 1,
#             "discNumber": 1,
#             "isStreamable": true,
#             "kind": "song",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview62/v4/09/52/62/095262e8-ebe9-c63e-88f9-4a092e80e8b4/mzaf_1026816634588384870.plus.aac.p.m4a",
#             "primaryGenreName": "Hip-Hop/Rap",
#             "releaseDate": "2011-11-01T12:00:00Z",
#             "trackCensoredName": "Thank You for Breathing (feat. \uc580\ud0a4 & \ubd09\ud0dc\uaddc)",
#             "trackCount": 5,
#             "trackExplicitness": "notExplicit",
#             "trackId": 1339457596,
#             "trackName": "Thank You for Breathing (feat. \uc580\ud0a4 & \ubd09\ud0dc\uaddc)",
#             "trackNumber": 4,
#             "trackPrice": 1.29,
#             "trackTimeMillis": 205342,
#             "trackViewUrl": "https://music.apple.com/us/album/thank-you-for-breathing-feat-%EC%96%80%ED%82%A4-%EB%B4%89%ED%83%9C%EA%B7%9C/1339457592?i=1339457596&uo=4",
#             "wrapperType": "track"
#         },
#         {
#             "artistId": 139334133,
#             "artistName": "Epik High",
#             "artistViewUrl": "https://music.apple.com/us/artist/epik-high/139334133?uo=4",
#             "artworkUrl100": "https://is3-ssl.mzstatic.com/image/thumb/Music114/v4/02/97/4a/02974ae9-89f9-8b0c-0338-662023eacd49/source/100x100bb.jpg",
#             "artworkUrl30": "https://is3-ssl.mzstatic.com/image/thumb/Music114/v4/02/97/4a/02974ae9-89f9-8b0c-0338-662023eacd49/source/30x30bb.jpg",
#             "artworkUrl60": "https://is3-ssl.mzstatic.com/image/thumb/Music114/v4/02/97/4a/02974ae9-89f9-8b0c-0338-662023eacd49/source/60x60bb.jpg",
#             "collectionCensoredName": "Epik High Is Here \u4e0a, Pt. 1",
#             "collectionExplicitness": "explicit",
#             "collectionId": 1548249682,
#             "collectionName": "Epik High Is Here \u4e0a, Pt. 1",
#             "collectionPrice": 9.99,
#             "collectionViewUrl": "https://music.apple.com/us/album/%EC%88%98%EC%83%81%EC%86%8C%EA%B0%90-acceptance-speech-feat-b-i/1548249682?i=1548249686&uo=4",
#             "country": "USA",
#             "currency": "USD",
#             "discCount": 1,
#             "discNumber": 1,
#             "isStreamable": true,
#             "kind": "song",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview114/v4/76/3d/4f/763d4f0d-6552-f8e0-f313-38cc1613a450/mzaf_11201973502917266106.plus.aac.p.m4a",
#             "primaryGenreName": "Hip-Hop/Rap",
#             "releaseDate": "2021-01-18T12:00:00Z",
#             "trackCensoredName": "\uc218\uc0c1\uc18c\uac10 (Acceptance Speech) [feat. B.I]",
#             "trackCount": 10,
#             "trackExplicitness": "notExplicit",
#             "trackId": 1548249686,
#             "trackName": "\uc218\uc0c1\uc18c\uac10 (Acceptance Speech) [feat. B.I]",
#             "trackNumber": 4,
#             "trackPrice": 1.29,
#             "trackTimeMillis": 196713,
#             "trackViewUrl": "https://music.apple.com/us/album/%EC%88%98%EC%83%81%EC%86%8C%EA%B0%90-acceptance-speech-feat-b-i/1548249682?i=1548249686&uo=4",
#             "wrapperType": "track"
#         },
#         {
#             "artistId": 139334133,
#             "artistName": "Epik High",
#             "artistViewUrl": "https://music.apple.com/us/artist/epik-high/139334133?uo=4",
#             "artworkUrl100": "https://is3-ssl.mzstatic.com/image/thumb/Music/v4/b7/be/45/b7be45cf-9eb1-216c-f6ff-5a630458e977/source/100x100bb.jpg",
#             "artworkUrl30": "https://is3-ssl.mzstatic.com/image/thumb/Music/v4/b7/be/45/b7be45cf-9eb1-216c-f6ff-5a630458e977/source/30x30bb.jpg",
#             "artworkUrl60": "https://is3-ssl.mzstatic.com/image/thumb/Music/v4/b7/be/45/b7be45cf-9eb1-216c-f6ff-5a630458e977/source/60x60bb.jpg",
#             "collectionCensoredName": "Pieces, Pt. One",
#             "collectionExplicitness": "explicit",
#             "collectionId": 412698049,
#             "collectionName": "Pieces, Pt. One",
#             "collectionPrice": 11.99,
#             "collectionViewUrl": "https://music.apple.com/us/album/one-feat-ji-sun/412698049?i=412698053&uo=4",
#             "country": "USA",
#             "currency": "USD",
#             "discCount": 1,
#             "discNumber": 1,
#             "isStreamable": true,
#             "kind": "song",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview19/v4/57/91/80/579180fd-de93-4afe-6f92-d38724115d84/mzaf_7357543515896070971.plus.aac.p.m4a",
#             "primaryGenreName": "K-Pop",
#             "releaseDate": "2008-04-17T12:00:00Z",
#             "trackCensoredName": "One (feat. Ji Sun)",
#             "trackCount": 18,
#             "trackExplicitness": "notExplicit",
#             "trackId": 412698053,
#             "trackName": "One (feat. Ji Sun)",
#             "trackNumber": 4,
#             "trackPrice": 1.29,
#             "trackTimeMillis": 230320,
#             "trackViewUrl": "https://music.apple.com/us/album/one-feat-ji-sun/412698049?i=412698053&uo=4",
#             "wrapperType": "track"
#         },
#         {
#             "artistId": 139334133,
#             "artistName": "Epik High",
#             "artistViewUrl": "https://music.apple.com/us/artist/epik-high/139334133?uo=4",
#             "artworkUrl100": "https://is3-ssl.mzstatic.com/image/thumb/Music114/v4/02/97/4a/02974ae9-89f9-8b0c-0338-662023eacd49/source/100x100bb.jpg",
#             "artworkUrl30": "https://is3-ssl.mzstatic.com/image/thumb/Music114/v4/02/97/4a/02974ae9-89f9-8b0c-0338-662023eacd49/source/30x30bb.jpg",
#             "artworkUrl60": "https://is3-ssl.mzstatic.com/image/thumb/Music114/v4/02/97/4a/02974ae9-89f9-8b0c-0338-662023eacd49/source/60x60bb.jpg",
#             "collectionCensoredName": "Epik High Is Here \u4e0a, Pt. 1",
#             "collectionExplicitness": "explicit",
#             "collectionId": 1548249682,
#             "collectionName": "Epik High Is Here \u4e0a, Pt. 1",
#             "collectionPrice": 9.99,
#             "collectionViewUrl": "https://music.apple.com/us/album/lesson-zero/1548249682?i=1548249683&uo=4",
#             "country": "USA",
#             "currency": "USD",
#             "discCount": 1,
#             "discNumber": 1,
#             "isStreamable": true,
#             "kind": "song",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview124/v4/24/ce/1b/24ce1b4a-81e0-6dab-f3b4-b5b9712475eb/mzaf_17663926044297618439.plus.aac.p.m4a",
#             "primaryGenreName": "Hip-Hop/Rap",
#             "releaseDate": "2021-01-18T12:00:00Z",
#             "trackCensoredName": "Lesson Zero",
#             "trackCount": 10,
#             "trackExplicitness": "notExplicit",
#             "trackId": 1548249683,
#             "trackName": "Lesson Zero",
#             "trackNumber": 1,
#             "trackPrice": 1.29,
#             "trackTimeMillis": 143430,
#             "trackViewUrl": "https://music.apple.com/us/album/lesson-zero/1548249682?i=1548249683&uo=4",
#             "wrapperType": "track"
#         },
#         {
#             "artistId": 139334133,
#             "artistName": "Epik High",
#             "artistViewUrl": "https://music.apple.com/us/artist/epik-high/139334133?uo=4",
#             "artworkUrl100": "https://is5-ssl.mzstatic.com/image/thumb/Music118/v4/82/48/4d/82484d36-358d-9e5a-f5b9-58004a4c895e/source/100x100bb.jpg",
#             "artworkUrl30": "https://is5-ssl.mzstatic.com/image/thumb/Music118/v4/82/48/4d/82484d36-358d-9e5a-f5b9-58004a4c895e/source/30x30bb.jpg",
#             "artworkUrl60": "https://is5-ssl.mzstatic.com/image/thumb/Music118/v4/82/48/4d/82484d36-358d-9e5a-f5b9-58004a4c895e/source/60x60bb.jpg",
#             "collectionCensoredName": "SHOEBOX",
#             "collectionExplicitness": "explicit",
#             "collectionId": 1316881090,
#             "collectionName": "SHOEBOX",
#             "collectionPrice": 11.99,
#             "collectionViewUrl": "https://music.apple.com/us/album/life-is-good-feat-jay-park/1316881090?i=1316881198&uo=4",
#             "country": "USA",
#             "currency": "USD",
#             "discCount": 1,
#             "discNumber": 1,
#             "isStreamable": true,
#             "kind": "song",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview128/v4/7f/b5/25/7fb52568-65b7-9575-6d26-2c4395cfd52e/mzaf_8795340300055639293.plus.aac.p.m4a",
#             "primaryGenreName": "Hip-Hop/Rap",
#             "releaseDate": "2014-10-21T12:00:00Z",
#             "trackCensoredName": "Life Is Good (feat. Jay Park)",
#             "trackCount": 12,
#             "trackExplicitness": "notExplicit",
#             "trackId": 1316881198,
#             "trackName": "Life Is Good (feat. Jay Park)",
#             "trackNumber": 10,
#             "trackPrice": 1.29,
#             "trackTimeMillis": 199907,
#             "trackViewUrl": "https://music.apple.com/us/album/life-is-good-feat-jay-park/1316881090?i=1316881198&uo=4",
#             "wrapperType": "track"
#         },
#         {
#             "artistId": 139334133,
#             "artistName": "Epik High",
#             "artistViewUrl": "https://music.apple.com/us/artist/epik-high/139334133?uo=4",
#             "artworkUrl100": "https://is3-ssl.mzstatic.com/image/thumb/Music114/v4/02/97/4a/02974ae9-89f9-8b0c-0338-662023eacd49/source/100x100bb.jpg",
#             "artworkUrl30": "https://is3-ssl.mzstatic.com/image/thumb/Music114/v4/02/97/4a/02974ae9-89f9-8b0c-0338-662023eacd49/source/30x30bb.jpg",
#             "artworkUrl60": "https://is3-ssl.mzstatic.com/image/thumb/Music114/v4/02/97/4a/02974ae9-89f9-8b0c-0338-662023eacd49/source/60x60bb.jpg",
#             "collectionCensoredName": "Epik High Is Here \u4e0a, Pt. 1",
#             "collectionExplicitness": "explicit",
#             "collectionId": 1548249682,
#             "collectionName": "Epik High Is Here \u4e0a, Pt. 1",
#             "collectionPrice": 9.99,
#             "collectionViewUrl": "https://music.apple.com/us/album/true-crime-feat-miso/1548249682?i=1548249689&uo=4",
#             "country": "USA",
#             "currency": "USD",
#             "discCount": 1,
#             "discNumber": 1,
#             "isStreamable": true,
#             "kind": "song",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview124/v4/46/cb/39/46cb3952-7b83-c054-07fc-508bdb44859e/mzaf_4022538532304479800.plus.aac.p.m4a",
#             "primaryGenreName": "Hip-Hop/Rap",
#             "releaseDate": "2021-01-18T12:00:00Z",
#             "trackCensoredName": "True Crime (feat. Miso)",
#             "trackCount": 10,
#             "trackExplicitness": "notExplicit",
#             "trackId": 1548249689,
#             "trackName": "True Crime (feat. Miso)",
#             "trackNumber": 7,
#             "trackPrice": 1.29,
#             "trackTimeMillis": 218134,
#             "trackViewUrl": "https://music.apple.com/us/album/true-crime-feat-miso/1548249682?i=1548249689&uo=4",
#             "wrapperType": "track"
#         },
#         {
#             "artistId": 139334133,
#             "artistName": "Epik High",
#             "artistViewUrl": "https://music.apple.com/us/artist/epik-high/139334133?uo=4",
#             "artworkUrl100": "https://is5-ssl.mzstatic.com/image/thumb/Music118/v4/82/48/4d/82484d36-358d-9e5a-f5b9-58004a4c895e/source/100x100bb.jpg",
#             "artworkUrl30": "https://is5-ssl.mzstatic.com/image/thumb/Music118/v4/82/48/4d/82484d36-358d-9e5a-f5b9-58004a4c895e/source/30x30bb.jpg",
#             "artworkUrl60": "https://is5-ssl.mzstatic.com/image/thumb/Music118/v4/82/48/4d/82484d36-358d-9e5a-f5b9-58004a4c895e/source/60x60bb.jpg",
#             "collectionCensoredName": "SHOEBOX",
#             "collectionExplicitness": "explicit",
#             "collectionId": 1316881090,
#             "collectionName": "SHOEBOX",
#             "collectionPrice": 11.99,
#             "collectionViewUrl": "https://music.apple.com/us/album/lesson-5-timeline/1316881090?i=1316881197&uo=4",
#             "country": "USA",
#             "currency": "USD",
#             "discCount": 1,
#             "discNumber": 1,
#             "isStreamable": true,
#             "kind": "song",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview128/v4/6a/c5/69/6ac569c9-e6a2-2450-5333-ffa807203280/mzaf_7119540204578903174.plus.aac.p.m4a",
#             "primaryGenreName": "Hip-Hop/Rap",
#             "releaseDate": "2014-10-21T12:00:00Z",
#             "trackCensoredName": "Lesson 5 (Timeline)",
#             "trackCount": 12,
#             "trackExplicitness": "notExplicit",
#             "trackId": 1316881197,
#             "trackName": "Lesson 5 (Timeline)",
#             "trackNumber": 9,
#             "trackPrice": 1.29,
#             "trackTimeMillis": 201196,
#             "trackViewUrl": "https://music.apple.com/us/album/lesson-5-timeline/1316881090?i=1316881197&uo=4",
#             "wrapperType": "track"
#         },
#         {
#             "artistId": 139334133,
#             "artistName": "Epik High",
#             "artistViewUrl": "https://music.apple.com/us/artist/epik-high/139334133?uo=4",
#             "artworkUrl100": "https://is3-ssl.mzstatic.com/image/thumb/Music114/v4/02/97/4a/02974ae9-89f9-8b0c-0338-662023eacd49/source/100x100bb.jpg",
#             "artworkUrl30": "https://is3-ssl.mzstatic.com/image/thumb/Music114/v4/02/97/4a/02974ae9-89f9-8b0c-0338-662023eacd49/source/30x30bb.jpg",
#             "artworkUrl60": "https://is3-ssl.mzstatic.com/image/thumb/Music114/v4/02/97/4a/02974ae9-89f9-8b0c-0338-662023eacd49/source/60x60bb.jpg",
#             "collectionCensoredName": "Epik High Is Here \u4e0a, Pt. 1",
#             "collectionExplicitness": "explicit",
#             "collectionId": 1548249682,
#             "collectionName": "Epik High Is Here \u4e0a, Pt. 1",
#             "collectionPrice": 9.99,
#             "collectionViewUrl": "https://music.apple.com/us/album/%EB%82%B4-%EC%96%98%EA%B8%B0-%EA%B0%99%EC%95%84-based-on-a-true-story-feat-heize/1548249682?i=1548249685&uo=4",
#             "country": "USA",
#             "currency": "USD",
#             "discCount": 1,
#             "discNumber": 1,
#             "isStreamable": true,
#             "kind": "song",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview124/v4/9a/7f/fb/9a7ffbbd-27ed-ab98-178b-f418e8758ab6/mzaf_15786091065089766174.plus.aac.p.m4a",
#             "primaryGenreName": "Hip-Hop/Rap",
#             "releaseDate": "2021-01-18T12:00:00Z",
#             "trackCensoredName": "\ub0b4 \uc598\uae30 \uac19\uc544 (Based On A True Story) [feat. HEIZE]",
#             "trackCount": 10,
#             "trackExplicitness": "notExplicit",
#             "trackId": 1548249685,
#             "trackName": "\ub0b4 \uc598\uae30 \uac19\uc544 (Based On A True Story) [feat. HEIZE]",
#             "trackNumber": 3,
#             "trackPrice": 1.29,
#             "trackTimeMillis": 234762,
#             "trackViewUrl": "https://music.apple.com/us/album/%EB%82%B4-%EC%96%98%EA%B8%B0-%EA%B0%99%EC%95%84-based-on-a-true-story-feat-heize/1548249682?i=1548249685&uo=4",
#             "wrapperType": "track"
#         },
#         {
#             "artistId": 159061696,
#             "artistName": "Tablo",
#             "artistViewUrl": "https://music.apple.com/us/artist/tablo/159061696?uo=4",
#             "artworkUrl100": "https://is4-ssl.mzstatic.com/image/thumb/Music128/v4/70/82/0e/70820ea7-c346-83a7-eba2-af632d41aec1/source/100x100bb.jpg",
#             "artworkUrl30": "https://is4-ssl.mzstatic.com/image/thumb/Music128/v4/70/82/0e/70820ea7-c346-83a7-eba2-af632d41aec1/source/30x30bb.jpg",
#             "artworkUrl60": "https://is4-ssl.mzstatic.com/image/thumb/Music128/v4/70/82/0e/70820ea7-c346-83a7-eba2-af632d41aec1/source/60x60bb.jpg",
#             "collectionCensoredName": "Fever's End, Pt. 1 - EP",
#             "collectionExplicitness": "notExplicit",
#             "collectionId": 1339095508,
#             "collectionName": "Fever's End, Pt. 1 - EP",
#             "collectionPrice": 3.99,
#             "collectionViewUrl": "https://music.apple.com/us/album/try-feat-%EB%B2%94%ED%82%A4/1339095508?i=1339095513&uo=4",
#             "country": "USA",
#             "currency": "USD",
#             "discCount": 1,
#             "discNumber": 1,
#             "isStreamable": true,
#             "kind": "song",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview128/v4/5d/99/20/5d99201a-de75-fd9c-7342-9a35a9dddaf3/mzaf_1113462573028684768.plus.aac.p.m4a",
#             "primaryGenreName": "Hip-Hop/Rap",
#             "releaseDate": "2011-10-21T12:00:00Z",
#             "trackCensoredName": "Try (feat. \ubc94\ud0a4)",
#             "trackCount": 5,
#             "trackExplicitness": "notExplicit",
#             "trackId": 1339095513,
#             "trackName": "Try (feat. \ubc94\ud0a4)",
#             "trackNumber": 5,
#             "trackPrice": 1.29,
#             "trackTimeMillis": 205822,
#             "trackViewUrl": "https://music.apple.com/us/album/try-feat-%EB%B2%94%ED%82%A4/1339095508?i=1339095513&uo=4",
#             "wrapperType": "track"
#         },
#         {
#             "artistId": 139334133,
#             "artistName": "Epik High",
#             "artistViewUrl": "https://music.apple.com/us/artist/epik-high/139334133?uo=4",
#             "artworkUrl100": "https://is5-ssl.mzstatic.com/image/thumb/Music118/v4/82/48/4d/82484d36-358d-9e5a-f5b9-58004a4c895e/source/100x100bb.jpg",
#             "artworkUrl30": "https://is5-ssl.mzstatic.com/image/thumb/Music118/v4/82/48/4d/82484d36-358d-9e5a-f5b9-58004a4c895e/source/30x30bb.jpg",
#             "artworkUrl60": "https://is5-ssl.mzstatic.com/image/thumb/Music118/v4/82/48/4d/82484d36-358d-9e5a-f5b9-58004a4c895e/source/60x60bb.jpg",
#             "collectionCensoredName": "SHOEBOX",
#             "collectionExplicitness": "explicit",
#             "collectionId": 1316881090,
#             "collectionName": "SHOEBOX",
#             "collectionPrice": 11.99,
#             "collectionViewUrl": "https://music.apple.com/us/album/amor-fati-feat-%EA%B9%80%EC%A2%85%EC%99%84/1316881090?i=1316881195&uo=4",
#             "country": "USA",
#             "currency": "USD",
# ...
#             "artworkUrl30": "https://is3-ssl.mzstatic.com/image/thumb/Music/v4/9d/4f/a2/9d4fa2bc-a6a6-60fd-1b39-e89efc4eccb6/source/30x30bb.jpg",
#             "artworkUrl60": "https://is3-ssl.mzstatic.com/image/thumb/Music/v4/9d/4f/a2/9d4fa2bc-a6a6-60fd-1b39-e89efc4eccb6/source/60x60bb.jpg",
#             "collectionCensoredName": "Lovescream",
#             "collectionExplicitness": "notExplicit",
#             "collectionId": 412844207,
#             "collectionName": "Lovescream",
#             "collectionPrice": 8.99,
#             "collectionViewUrl": "https://music.apple.com/us/album/harajuku-days/412844207?i=412844210&uo=4",
#             "country": "USA",
#             "currency": "USD",
#             "discCount": 1,
#             "discNumber": 1,
#             "isStreamable": true,
#             "kind": "song",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview71/v4/2c/e9/33/2ce933be-b9b1-31a3-287e-316a43290ce5/mzaf_8378743880942256113.plus.aac.p.m4a",
#             "primaryGenreName": "K-Pop",
#             "releaseDate": "2008-09-30T12:00:00Z",
#             "trackCensoredName": "Harajuku Days",
#             "trackCount": 7,
#             "trackExplicitness": "notExplicit",
#             "trackId": 412844210,
#             "trackName": "Harajuku Days",
#             "trackNumber": 3,
#             "trackPrice": 1.29,
#             "trackTimeMillis": 130173,
#             "trackViewUrl": "https://music.apple.com/us/album/harajuku-days/412844207?i=412844210&uo=4",
#             "wrapperType": "track"
#         },
#         {
#             "artistId": 281891356,
#             "artistName": "Gallant, Tablo & Eric Nam",
#             "artistViewUrl": "https://music.apple.com/us/artist/gallant/281891356?uo=4",
#             "artworkUrl100": "https://is1-ssl.mzstatic.com/image/thumb/Music128/v4/2b/d5/35/2bd53510-f330-8435-a400-ad44f7721d06/source/100x100bb.jpg",
#             "artworkUrl30": "https://is1-ssl.mzstatic.com/image/thumb/Music128/v4/2b/d5/35/2bd53510-f330-8435-a400-ad44f7721d06/source/30x30bb.jpg",
#             "artworkUrl60": "https://is1-ssl.mzstatic.com/image/thumb/Music128/v4/2b/d5/35/2bd53510-f330-8435-a400-ad44f7721d06/source/60x60bb.jpg",
#             "collectionCensoredName": "Cave Me In (Raiden Remix) - Single",
#             "collectionExplicitness": "notExplicit",
#             "collectionId": 1257804258,
#             "collectionName": "Cave Me In (Raiden Remix) - Single",
#             "collectionPrice": 1.29,
#             "collectionViewUrl": "https://music.apple.com/us/album/cave-me-in-raiden-remix/1257804258?i=1257804337&uo=4",
#             "country": "USA",
#             "currency": "USD",
#             "discCount": 1,
#             "discNumber": 1,
#             "isStreamable": true,
#             "kind": "song",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview118/v4/f4/7e/78/f47e78f4-3b4e-5efd-fa1f-c22acecfd5f3/mzaf_7120358738474466818.plus.aac.p.m4a",
#             "primaryGenreName": "R&B/Soul",
#             "releaseDate": "2017-09-22T12:00:00Z",
#             "trackCensoredName": "Cave Me In (Raiden Remix)",
#             "trackCount": 1,
#             "trackExplicitness": "notExplicit",
#             "trackId": 1257804337,
#             "trackName": "Cave Me In (Raiden Remix)",
#             "trackNumber": 1,
#             "trackPrice": 1.29,
#             "trackTimeMillis": 221537,
#             "trackViewUrl": "https://music.apple.com/us/album/cave-me-in-raiden-remix/1257804258?i=1257804337&uo=4",
#             "wrapperType": "track"
#         },
#         {
#             "artistId": 139334133,
#             "artistName": "Epik High",
#             "artistViewUrl": "https://music.apple.com/us/artist/epik-high/139334133?uo=4",
#             "artworkUrl100": "https://is1-ssl.mzstatic.com/image/thumb/Music/v4/72/a3/46/72a346b5-0fe5-dea4-17a0-4c17fca4cc61/source/100x100bb.jpg",
#             "artworkUrl30": "https://is1-ssl.mzstatic.com/image/thumb/Music/v4/72/a3/46/72a346b5-0fe5-dea4-17a0-4c17fca4cc61/source/30x30bb.jpg",
#             "artworkUrl60": "https://is1-ssl.mzstatic.com/image/thumb/Music/v4/72/a3/46/72a346b5-0fe5-dea4-17a0-4c17fca4cc61/source/60x60bb.jpg",
#             "collectionCensoredName": "High Society",
#             "collectionExplicitness": "explicit",
#             "collectionId": 412837812,
#             "collectionName": "High Society",
#             "collectionPrice": 11.99,
#             "collectionViewUrl": "https://music.apple.com/us/album/%ED%98%BC%EC%9E%90%EB%9D%BC%EB%8F%84-feat-clazziquai/412837812?i=412837828&uo=4",
#             "country": "USA",
#             "currency": "USD",
#             "discCount": 1,
#             "discNumber": 1,
#             "isStreamable": true,
#             "kind": "song",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/Music/fd/0a/0c/mzi.jbbpivlc.aac.p.m4a",
#             "primaryGenreName": "K-Pop",
#             "releaseDate": "2004-07-26T12:00:00Z",
#             "trackCensoredName": "\ud63c\uc790\ub77c\ub3c4 (feat. Clazziquai)",
#             "trackCount": 18,
#             "trackExplicitness": "notExplicit",
#             "trackId": 412837828,
#             "trackName": "\ud63c\uc790\ub77c\ub3c4 (feat. Clazziquai)",
#             "trackNumber": 13,
#             "trackPrice": 1.29,
#             "trackTimeMillis": 254360,
#             "trackViewUrl": "https://music.apple.com/us/album/%ED%98%BC%EC%9E%90%EB%9D%BC%EB%8F%84-feat-clazziquai/412837812?i=412837828&uo=4",
#             "wrapperType": "track"
#         },
#         {
#             "artistId": 139334133,
#             "artistName": "Epik High",
#             "artistViewUrl": "https://music.apple.com/us/artist/epik-high/139334133?uo=4",
#             "artworkUrl100": "https://is4-ssl.mzstatic.com/image/thumb/Music128/v4/ad/4c/fa/ad4cfa21-25c1-db99-5b7c-0ec3f1b60334/source/100x100bb.jpg",
#             "artworkUrl30": "https://is4-ssl.mzstatic.com/image/thumb/Music128/v4/ad/4c/fa/ad4cfa21-25c1-db99-5b7c-0ec3f1b60334/source/30x30bb.jpg",
#             "artworkUrl60": "https://is4-ssl.mzstatic.com/image/thumb/Music128/v4/ad/4c/fa/ad4cfa21-25c1-db99-5b7c-0ec3f1b60334/source/60x60bb.jpg",
#             "collectionArtistId": 547186469,
#             "collectionArtistName": "YG Family",
#             "collectionArtistViewUrl": "https://music.apple.com/us/artist/yg-family/547186469?uo=4",
#             "collectionCensoredName": "2014 YG FAMILY CONCERT IN SEOUL LIVE",
#             "collectionExplicitness": "notExplicit",
#             "collectionId": 1314318144,
#             "collectionName": "2014 YG FAMILY CONCERT IN SEOUL LIVE",
#             "collectionPrice": -1.0,
#             "collectionViewUrl": "https://music.apple.com/us/album/umbrella-feat-suhyun-live/1314318144?i=1314318159&uo=4",
#             "country": "USA",
#             "currency": "USD",
#             "discCount": 3,
#             "discNumber": 1,
#             "isStreamable": true,
#             "kind": "song",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview118/v4/cb/b1/2b/cbb12b6c-8bc3-126c-27e1-b59a26525179/mzaf_2036167311042158366.plus.aac.p.m4a",
#             "primaryGenreName": "Pop",
#             "releaseDate": "2014-11-28T12:00:00Z",
#             "trackCensoredName": "Umbrella (feat. SUHYUN) [Live]",
#             "trackCount": 11,
#             "trackExplicitness": "notExplicit",
#             "trackId": 1314318159,
#             "trackName": "Umbrella (feat. SUHYUN)",
#             "trackNumber": 7,
#             "trackPrice": 1.29,
#             "trackTimeMillis": 272051,
#             "trackViewUrl": "https://music.apple.com/us/album/umbrella-feat-suhyun-live/1314318144?i=1314318159&uo=4",
#             "wrapperType": "track"
#         },
#         {
#             "artistId": 139334133,
#             "artistName": "Epik High",
#             "artistViewUrl": "https://music.apple.com/us/artist/epik-high/139334133?uo=4",
#             "artworkUrl100": "https://is4-ssl.mzstatic.com/image/thumb/Music128/v4/ad/4c/fa/ad4cfa21-25c1-db99-5b7c-0ec3f1b60334/source/100x100bb.jpg",
#             "artworkUrl30": "https://is4-ssl.mzstatic.com/image/thumb/Music128/v4/ad/4c/fa/ad4cfa21-25c1-db99-5b7c-0ec3f1b60334/source/30x30bb.jpg",
#             "artworkUrl60": "https://is4-ssl.mzstatic.com/image/thumb/Music128/v4/ad/4c/fa/ad4cfa21-25c1-db99-5b7c-0ec3f1b60334/source/60x60bb.jpg",
#             "collectionArtistId": 547186469,
#             "collectionArtistName": "YG Family",
#             "collectionArtistViewUrl": "https://music.apple.com/us/artist/yg-family/547186469?uo=4",
#             "collectionCensoredName": "2014 YG FAMILY CONCERT IN SEOUL LIVE",
#             "collectionExplicitness": "notExplicit",
#             "collectionId": 1314318144,
#             "collectionName": "2014 YG FAMILY CONCERT IN SEOUL LIVE",
#             "collectionPrice": -1.0,
#             "collectionViewUrl": "https://music.apple.com/us/album/love-love-love-feat-dara-live/1314318144?i=1314318160&uo=4",
#             "country": "USA",
#             "currency": "USD",
#             "discCount": 3,
#             "discNumber": 1,
#             "isStreamable": true,
#             "kind": "song",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview128/v4/f7/1f/ea/f71fea1f-4dde-eb04-865c-b496b5d46a28/mzaf_5741152046076846616.plus.aac.p.m4a",
#             "primaryGenreName": "Pop",
#             "releaseDate": "2014-11-28T12:00:00Z",
#             "trackCensoredName": "Love Love Love (feat. DARA) [Live]",
#             "trackCount": 11,
#             "trackExplicitness": "notExplicit",
#             "trackId": 1314318160,
#             "trackName": "Love Love Love (feat. DARA)",
#             "trackNumber": 8,
#             "trackPrice": 1.29,
#             "trackTimeMillis": 230626,
#             "trackViewUrl": "https://music.apple.com/us/album/love-love-love-feat-dara-live/1314318144?i=1314318160&uo=4",
#             "wrapperType": "track"
#         },
#         {
#             "artistId": 139334133,
#             "artistName": "Epik High",
#             "artistViewUrl": "https://music.apple.com/us/artist/epik-high/139334133?uo=4",
#             "artworkUrl100": "https://is1-ssl.mzstatic.com/image/thumb/Music/v4/72/a3/46/72a346b5-0fe5-dea4-17a0-4c17fca4cc61/source/100x100bb.jpg",
#             "artworkUrl30": "https://is1-ssl.mzstatic.com/image/thumb/Music/v4/72/a3/46/72a346b5-0fe5-dea4-17a0-4c17fca4cc61/source/30x30bb.jpg",
#             "artworkUrl60": "https://is1-ssl.mzstatic.com/image/thumb/Music/v4/72/a3/46/72a346b5-0fe5-dea4-17a0-4c17fca4cc61/source/60x60bb.jpg",
#             "collectionCensoredName": "High Society",
#             "collectionExplicitness": "explicit",
#             "collectionId": 412837812,
#             "collectionName": "High Society",
#             "collectionPrice": 11.99,
#             "collectionViewUrl": "https://music.apple.com/us/album/lesson-2-sunset/412837812?i=412837820&uo=4",
#             "country": "USA",
#             "currency": "USD",
#             "discCount": 1,
#             "discNumber": 1,
#             "isStreamable": true,
#             "kind": "song",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview71/v4/4d/0d/f3/4d0df3b9-420c-b9e6-c02b-6c5b572d7435/mzaf_761421072250920458.plus.aac.p.m4a",
#             "primaryGenreName": "K-Pop",
#             "releaseDate": "2004-07-26T12:00:00Z",
#             "trackCensoredName": "Lesson 2 (Sunset)",
#             "trackCount": 18,
#             "trackExplicitness": "notExplicit",
#             "trackId": 412837820,
#             "trackName": "Lesson 2 (Sunset)",
#             "trackNumber": 5,
#             "trackPrice": 1.29,
#             "trackTimeMillis": 240733,
#             "trackViewUrl": "https://music.apple.com/us/album/lesson-2-sunset/412837812?i=412837820&uo=4",
#             "wrapperType": "track"
#         },
#         {
#             "artistId": 139334133,
#             "artistName": "Epik High",
#             "artistViewUrl": "https://music.apple.com/us/artist/epik-high/139334133?uo=4",
#             "artworkUrl100": "https://is4-ssl.mzstatic.com/image/thumb/Music128/v4/ad/4c/fa/ad4cfa21-25c1-db99-5b7c-0ec3f1b60334/source/100x100bb.jpg",
#             "artworkUrl30": "https://is4-ssl.mzstatic.com/image/thumb/Music128/v4/ad/4c/fa/ad4cfa21-25c1-db99-5b7c-0ec3f1b60334/source/30x30bb.jpg",
#             "artworkUrl60": "https://is4-ssl.mzstatic.com/image/thumb/Music128/v4/ad/4c/fa/ad4cfa21-25c1-db99-5b7c-0ec3f1b60334/source/60x60bb.jpg",
#             "collectionArtistId": 547186469,
#             "collectionArtistName": "YG Family",
#             "collectionArtistViewUrl": "https://music.apple.com/us/artist/yg-family/547186469?uo=4",
#             "collectionCensoredName": "2014 YG FAMILY CONCERT IN SEOUL LIVE",
#             "collectionExplicitness": "notExplicit",
#             "collectionId": 1314318144,
#             "collectionName": "2014 YG FAMILY CONCERT IN SEOUL LIVE",
#             "collectionPrice": -1.0,
#             "collectionViewUrl": "https://music.apple.com/us/album/fly-live/1314318144?i=1314318158&uo=4",
#             "country": "USA",
#             "currency": "USD",
#             "discCount": 3,
#             "discNumber": 1,
#             "isStreamable": true,
#             "kind": "song",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview128/v4/8f/b2/e5/8fb2e5ef-f355-9ba0-acba-9c6b98a7c4ce/mzaf_3171657103576954719.plus.aac.p.m4a",
#             "primaryGenreName": "Pop",
#             "releaseDate": "2014-11-28T12:00:00Z",
#             "trackCensoredName": "Fly (Live)",
#             "trackCount": 11,
#             "trackExplicitness": "notExplicit",
#             "trackId": 1314318158,
#             "trackName": "Fly",
#             "trackNumber": 6,
#             "trackPrice": 1.29,
#             "trackTimeMillis": 267598,
#             "trackViewUrl": "https://music.apple.com/us/album/fly-live/1314318144?i=1314318158&uo=4",
#             "wrapperType": "track"
#         },
#         {
#             "artistId": 1318862570,
#             "artistName": "End of the World & Epik High",
#             "artistViewUrl": "https://music.apple.com/us/artist/end-of-the-world/1318862570?uo=4",
#             "artworkUrl100": "https://is1-ssl.mzstatic.com/image/thumb/Music125/v4/5d/7f/d0/5d7fd019-3111-a233-43c5-a5c2deab63f2/source/100x100bb.jpg",
#             "artworkUrl30": "https://is1-ssl.mzstatic.com/image/thumb/Music125/v4/5d/7f/d0/5d7fd019-3111-a233-43c5-a5c2deab63f2/source/30x30bb.jpg",
#             "artworkUrl60": "https://is1-ssl.mzstatic.com/image/thumb/Music125/v4/5d/7f/d0/5d7fd019-3111-a233-43c5-a5c2deab63f2/source/60x60bb.jpg",
#             "collectionCensoredName": "Sleeping Beauty (Digital Farm Animals Remix) - Single",
#             "collectionExplicitness": "notExplicit",
#             "collectionId": 1409774781,
#             "collectionName": "Sleeping Beauty (Digital Farm Animals Remix) - Single",
#             "collectionPrice": 1.29,
#             "collectionViewUrl": "https://music.apple.com/us/album/sleeping-beauty-digital-farm-animals-remix/1409774781?i=1409775156&uo=4",
#             "country": "USA",
#             "currency": "USD",
#             "discCount": 1,
#             "discNumber": 1,
#             "isStreamable": true,
#             "kind": "song",
#             "previewUrl": "https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview125/v4/41/9c/31/419c318e-e28d-7e80-c6e5-a2d3c3e5694e/mzaf_2326570012928186728.plus.aac.p.m4a",
#             "primaryGenreName": "Pop",
#             "releaseDate": "2018-07-20T12:00:00Z",
#             "trackCensoredName": "Sleeping Beauty (Digital Farm Animals Remix)",
#             "trackCount": 1,
#             "trackExplicitness": "notExplicit",
#             "trackId": 1409775156,
#             "trackName": "Sleeping Beauty (Digital Farm Animals Remix)",
#             "trackNumber": 1,
#             "trackPrice": 1.29,
#             "trackTimeMillis": 219067,
#             "trackViewUrl": "https://music.apple.com/us/album/sleeping-beauty-digital-farm-animals-remix/1409774781?i=1409775156&uo=4",
#             "wrapperType": "track"
#         }
#     ]
# }

# %%
# STORE
# ============================
# Storing the data into a dataframe
EH = pd.DataFrame.from_dict(data)

# %% [markdown]
# ### Question 2

# %% [markdown]
# * *collectionId*
#   * As *collectionId* appears to be a numerical ID for an album, I would guess that this is a qualitative, discrete, and nominal attribute? It isn't clear how the IDs are assigned and when comparing the IDs of their most recent albums there doesn't appear to be an overarching pattern. Based on this very limited dataset, I feel most comfortable with claiming it as a nominal attribute rather than an ordinal one.
# * *trackPrice*
#   * This is a quantitative, continuous ratio. A difference (+ or -) and a ratio ($\times$ or $\div$) between two *trackPrice* attributes are thought to be meaningful.
# * *trackTimeMillis*
#   * This is a quantitative, continuous ratio. Because the units of analysis are taking the form of XXX milliseconds rather than xx:xx:xx, we can still arrive at a meaningful value either through a difference and a ratio.
# * *primaryGenreName*
#   * This is a qualitative, discrete, and nominal attribute. The *primaryGenreName* attribute, in it of itself, only provides enough information to distinguish one song from another.
# * *contentAdvisoryRating*
#   * This is a qualitative, discrete, nominal, binary attribute as there are only two options: Explicit or NaN.
# * *isStreamable*
#   * This is a qualitative, discrete, nominal, binary attribute as it only consists of two options: True or False.

# %% [markdown]
# ### Question 3

# %% [markdown]
# A situation where the identification numbers (ID) would be useful would be if the ID was an ordinal attribute, interval or a ratio. That is to say, if the ID took on a meaningful value in comparison to another ID, similar to the Dewey Decimal System, then we can make a prediction based on ID itself.

# %% [markdown]
# ### Question 4

# %% [markdown]
# #### Part A

# %%
#Determining the number of missing values per variable
EH.isna().sum()
# Out:
# wrapperType                  0
# kind                         0
# artistId                     0
# collectionId                 0
# trackId                      0
# artistName                   0
# collectionName               0
# trackName                    0
# collectionCensoredName       0
# trackCensoredName            0
# artistViewUrl                0
# collectionViewUrl            0
# trackViewUrl                 0
# previewUrl                   0
# artworkUrl30                 0
# artworkUrl60                 0
# artworkUrl100                0
# collectionPrice              0
# trackPrice                   0
# releaseDate                  0
# collectionExplicitness       0
# trackExplicitness            0
# discCount                    0
# discNumber                   0
# trackCount                   0
# trackNumber                  0
# trackTimeMillis              0
# country                      0
# currency                     0
# primaryGenreName             0
# contentAdvisoryRating      179
# isStreamable                 0
# collectionArtistId         194
# collectionArtistName       194
# collectionArtistViewUrl    196
# dtype: int64

# %% [markdown]
# #### Part B

# %%
#Determining the average trackPrice
EH['trackPrice'].mean()
# Out:
# 1.2149999999999996

# %% [markdown]
# #### Part C

# %%
#Determining the number of songs that are explicit and not explicit
EH["trackExplicitness"].value_counts()
# Out:
# notExplicit    179
# explicit        21
# Name: trackExplicitness, dtype: int64

# %% [markdown]
# ### Question 5

# %%
# Creating a function
def play_time(dta): 
    '''
    This function takes the millisecond playtime of each song and converts it into a tuple format of (minutes, seconds).

    Args:
        dta (pandas column): a pandas dataframe column to be processed one row at a time

    Returns:
        album_time (list): list containing all the tuples of playtime per song
    '''
    album_time = []
    for time in dta:
        minutes = int(np.floor(time/60000)) # Using numpy floor to round down the minutes
        seconds = int(np.floor((time - (minutes * 60000))/1000)) # Using numpy floor to round down the seconds
        album_time.append((minutes, seconds))
    return album_time

# %% [markdown]
# ### Question 6

# %%
# Outputting the playtime tuples of the first 5 songs
play_time(EH['trackTimeMillis'].head(5))
# Out:
# [(5, 27), (3, 33), (3, 43), (4, 12), (3, 50)]

# %% [markdown]
# ## Bonus

# %%
# Reviewing the website
webpage = 'http://jse.amstat.org/jse_data_archive.htm'

#Checking access 
server_response = requests.get(webpage)

#Parsing
soup = BeautifulSoup(server_response.text, features="html.parser")

# %%
# Creating a list of dictionaries that indicates if a file is missing or not
links_list = []
for tag in soup.find_all('a'):
    link = tag['href']
    name = tag.text
    host = 'http://jse.amstat.org/'
    if name[-3:] == 'txt':
        if str((requests.get(host + link)).status_code) != '200': # Coverting the status code into a string 
            missing = 'yes' # Creating a 'missing' variable to track what files are missing
        else:
            missing = 'no'
        links_list.append({'link': link, 'name': name, 'missing a file?': missing})

# %%
# Storing list of links as csv file
with open('data_links.csv', 'w') as csvfile:
    fieldnames = ['link', 'name', 'missing a file?']
    writer = csv.DictWriter(csvfile, fieldnames)
    writer.writeheader()
    for link in links_list:
        writer.writerow(link)
    print('Links added to file: ' + str(len(links_list)))
# Out:
# Links added to file: 209

# %%
# Outputting the first 5 rows of the CSV
pd.read_csv('data_links.csv')[:5]
# Out:
#                       link            name missing a file?
# 0          v9n2/4cdata.txt      4cdata.txt             yes
# 1         v9n2/4c1data.txt     4c1data.txt             yes
# 2              v9n2/4c.txt          4c.txt             yes
# 3  datasets/93cars.dat.txt  93cars.dat.txt              no
# 4      datasets/93cars.txt      93cars.txt              no
